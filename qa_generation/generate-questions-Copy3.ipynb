# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
fname = "test_fold_two"
basepath = "./-paraphrase-multilingual-MiniLM-L12-v2_3015"

# %% [markdown]
# ## Load data

# %%
import pandas as pd

def loadData(fname, basepath):
    sample = pd.read_csv(f"{basepath}/{fname}.csv")
    sample['Document'] = sample.apply(lambda row: ': '.join(row.astype(str)), axis=1)
    return sample

# %% [markdown]
# ## Question Generation

# %%
from qa_generation import QAGenerator
from prompt_factory import PromptFactory
from tqdm.notebook import tqdm

template = '''
        Gedraag je als een {role} die online informatie zoekt.
        Patiënten stellen meestal vragen als:
{{
    "qa_list": [
        {{
            "question": "Hoe kan ik een verstopte voedingssonde doorspoelen?",
            "answer": "Om een verstopte voedingssonde door te spoelen, kunt u de volgende stappen proberen: 1. Sluit de spuit rechtstreeks aan op de sonde (niet op het voedingssysteem). Als er een verstopping is in het voedingssysteem, kunt u dit vervangen. 2. Neem een spuit van 10 cc en spuit met lichte druk lauwwarm water door de voedingssonde. Herhaal dit zo nodig nog een keer. 3. Als het oplossen van de verstopping niet lukt, laat dan lauwwarm water 30 minuten inwerken en herhaal de bovenstaande procedure nogmaals. 4. Als u de verstopping kunt zien, kunt u proberen om de voedingssonde op die plek zachtjes te kneden. Als de verstopping dan loskomt, kunt u het doorspuiten met lauwwarm water. Belangrijk: Gebruik nooit een voerdraad of koolzuurhoudend bronwater of frisdranken, omdat dit kan leiden tot perforatie. Daarnaast wordt het afraden om natriumbicarbonaat te gebruiken als medicatie de oorzaak is van de verstopping, omdat dit de verstopping groter kan maken."
        }}
    ]
}}


        in het json formaat: 
        {format}

Document Informatie:
        {document}

        Belangrijke Opmerking: Bij het genereren van vragen, gebruik specifieke termen en benamingen uit het document in plaats van algemene termen zoals 'dit onderzoek' of 'die procedure'. Verwijs direct naar de procedure of het document met de exacte naam om nauwkeurigheid en duidelijkheid in de vragen te waarborgen. Vermijd algemeenheden en zorg ervoor dat elke vraag direct gerelateerd is aan de verstrekte documentinformatie.


        Stel {n} vragen die beantwoord kunnen worden op basis van deze paragraaf in het formaat:
        {format}

        Zorg ervoor dat elke vraag en antwoord paar in een geldig JSON-formaat is. Dit betekent dat vragen en antwoorden tussen dubbele aanhalingstekens moeten staan, en de algemene structuur moet overeenkomen met het vereiste JSON-schema.
        '''

roles = [
    'Patiënt',
    'Nieuwe Ouder',
    'Oudere Patiënt',
    'Persoon die een Tweede Mening Zoekt',
    'Reiziger die Medisch Advies Na Reizen Zoekt',
    'Zorgverlener die Informatie Zoekt']

prompt_factory = PromptFactory(prompt=template,roles=roles)

num_questions_per_doc = 5

QAGenerator = QAGenerator()
# Generate the data
import pandas as pd
from tqdm import tqdm


def generateQuestions(df):
    data = []
    for index, row in tqdm(df.iterrows(), total=df.shape[0],desc="Generating QAs"):
        doc = row["Document"]
        # Do something with col1 and col2
        try:
            for i in range(2):
                qa_list = QAGenerator.generate_qas(prompt_factory.generate_prompt(doc, num_questions_per_doc))
                for qa in qa_list:
                    new_row = row.to_dict()
                    new_row['Question'] = qa.question
                    new_row['Answer'] = qa.answer
                    data.append(new_row)

        except Exception as e:
                print(f"Failed to generate QA for doc: {doc[:100]}. Error: {e}")
                continue
    if(len(data) == 0):
       return pd.DataFrame()
    result = pd.DataFrame(data)
    result = result.dropna(subset=['Document', 'Question', 'Answer'])
    result = result[(result['Document'] != '') & (result['Question'] != '') & (result['Answer'] != '')]
    return result

# %%
from fact_qa import FactQAGenerator
from prompt_factory import PromptFactory
import langchain

template = '''
Gedraag je als iemand die online informatie zoekt en stelt vragen gebaseerd op specifieke feiten zoals locatie, telefoonnummer, naam, enzovoort.

Patiënten of gebruikers kunnen bijvoorbeeld vragen stellen als:
{{
    "qa_list": [
        {{
            "question": "Wat is het telefoonnummer van de kliniek voor noodgevallen?",
            "answer": "Het telefoonnummer van de kliniek voor noodgevallen is 012-345-6789."
        }},
        {{
            "question": "Waar is de hoofdingang van het ziekenhuis gelegen?",
            "answer": "De hoofdingang van het ziekenhuis is gelegen aan de Eerste Gezondheidsstraat 123 in Amsterdam."
        }}
        // meer vragen en antwoorden gebaseerd op specifieke feiten
    ]
}}

in het json formaat:
{format}

Document Informatie:
{document}

Belangrijke Opmerking: Bij het genereren van vragen, gebruik specifieke termen en benamingen uit het document in plaats van algemene termen. Verwijs direct naar de specifieke feit (zoals locatie, telefoonnummer, naam) om nauwkeurigheid en duidelijkheid in de vragen te waarborgen. Vermijd algemeenheden.

Maak vragen die beantwoord kunnen worden met de volgende informatie: {fact}

Stel {n} vragen die beantwoord kunnen worden op basis van deze paragraaf in het formaat:
{format}

Zorg ervoor dat elke vraag en antwoord paar in een geldig JSON-formaat is. Dit betekent dat vragen en antwoorden tussen dubbele aanhalingstekens moeten staan, en de algemene structuur moet overeenkomen met het vereiste JSON-schema.
        '''

base_prompt = langchain.PromptTemplate(
            template=template,
            input_variables=['fact', 'n', 'document', 'format']
        )

num_questions_per_doc = 5

FactQAGenerator = FactQAGenerator()

def generateFactQuestions(df):
    data = []
    # Generate the data
    for index, row in tqdm(df.iterrows(), total=df.shape[0],desc="Generating Fact QAs"):
        doc = row['Document']
        # Assuming phone numbers are separated by commas
        facts = row['Context Entities']
        try:
            for i in range(2):
                for entity in extract_desired_entities(facts)[:5]:
                    fact = entity["value"]
                    prompt = base_prompt.partial(
                        n=num_questions_per_doc,
                        document=doc)
                    try:
                        qa_list = FactQAGenerator.generate_question_for_fact(prompt, fact)
                        for qa in qa_list:
                            new_row = row.to_dict()
                            new_row['Question'] = qa.question
                            new_row['Answer'] = qa.answer
                            new_row['Fact'] = entity
                            print(entity)
                            data.append(new_row)
                    except:
                        pass
        except Exception as e:
                print(f"Failed to generate QA for document: {doc[:20]}. Error: {e:20}")

    if(len(data) == 0):
        return pd.DataFrame()

    result = pd.DataFrame(data)
    result = result.dropna(subset=['Document', 'Question', 'Answer'])
    result = result[(result['Document'] != '') & (result['Question'] != '') & (result['Answer'] != '')]
    return result

# %%
def update_df_with_lambda(df, column_name, lambda_function):
     # Check if the column does not exist in the DataFrame, if not, initialize it with NA
    if column_name not in df.columns:
        df[column_name] = pd.NA
    
    # Apply the lambda function only to rows where the column value is NA
    df[column_name] = df.apply(lambda row: lambda_function(row) if pd.isna(row[column_name]) else row[column_name], axis=1)
    return df

# %% [raw]
# ## BLEU / ROUGE filters

# %%
from answer_context_filter import calculate_bleu_score, calculate_rouge_score

def calculate_scores(df):
    # Calculate BLEU and ROUGE scores
    #df['Question-Context BLEU'] = df.apply(lambda row: calculate_bleu_score(row['Document'], row['Question']), axis=1)
    #df['Answer-Context BLEU'] = df.apply(lambda row: calculate_bleu_score(row['Document'], row['Answer']), axis=1)

    #df['Question-Context ROUGE'] = df.apply(lambda row: calculate_rouge_score(row['Document'], row['Question']), axis=1)
    #df['Answer-Context ROUGE'] = df.apply(lambda row: calculate_rouge_score(row['Document'], row['Answer']), axis=1)
    #df['Question-Context ROUGE-L F1'] = df['Question-Context ROUGE'].apply(lambda x: x[0]['rouge-l']['f'] if x else None)
    #df['Answer-Context ROUGE-L F1'] = df['Answer-Context ROUGE'].apply(lambda x: x[0]['rouge-l']['f'] if x else None)

    df = update_df_with_lambda(
        df, 'Question-Context ROUGE',
        lambda row: calculate_rouge_score(row['Document'], row['Question']) if pd.isna(row.get('Question-Context ROUGE')) else row['Question-Context ROUGE']
    )

    # Update 'Answer-Context ROUGE' only if it is NA
    df = update_df_with_lambda(
        df, 'Answer-Context ROUGE',
        lambda row: calculate_rouge_score(row['Document'], row['Answer']) if pd.isna(row.get('Answer-Context ROUGE')) else row['Answer-Context ROUGE']
    )

    # Update 'Question-Context ROUGE-L F1' based on the 'Question-Context ROUGE' column, only if it is NA
    df = update_df_with_lambda(
        df, 'Question-Context ROUGE-L F1',
        lambda row: row['Question-Context ROUGE'][0]['rouge-l']['f'] if pd.isna(row.get('Question-Context ROUGE-L F1')) and row['Question-Context ROUGE'] else None
    )

    # Update 'Answer-Context ROUGE-L F1' based on the 'Answer-Context ROUGE' column, only if it is NA
    df = update_df_with_lambda(
        df, 'Answer-Context ROUGE-L F1',
        lambda row: row['Answer-Context ROUGE'][0]['rouge-l']['f'] if pd.isna(row.get('Answer-Context ROUGE-L F1')) and row['Answer-Context ROUGE'] else None
    )

    return df


def rougeFilter(df):
    df = calculate_scores(df)
    df = df[df['Answer-Context ROUGE-L F1'] > 0.1]
    return df

# %% [markdown]
# ## Vector filter

# %%
from vector_filter import precompute_embeddings
from vector_filter import filter_dataframe

def vectorFilter(df):
    df["Embedding"] = precompute_embeddings(df, 'Question')
    df = filter_dataframe(df, threshold=0.9)
    return df

# %% [markdown]
# ## Entity Filter

# %%
def contains_all_elements(list1, list2):
    """
    Check if list1 contains all elements of list2.
    Each element is a dictionary with 'entityType' and 'value' keys.
    """
    # Convert each dictionary in the lists to a tuple (entityType, value) for easy comparison
    #set1 = {tuple(d.items()) for d in list1}
    #set2 = {tuple(d.items()) for d in list2}
    set1 = {d['value'] for d in list1 if 'value' in d}
    set2 = {d['value'] for d in list2 if 'value' in d}

    # Check if every element in set2 is also in set1
    return set2.issubset(set1)

def check_entity_match(row):
    return contains_all_elements(row['Context Entities'], row['Answer Entities'])

# Apply the function to each row to create the new column

# %%
from extract import extract_all_entities

def extractEntities(df):
    df['Context Entities'] = df['Document'].apply(extract_all_entities)
    df['Question Entities'] = df['Question'].apply(extract_all_entities)
    df['Answer Entities'] = df['Answer'].apply(extract_all_entities)
    df['Entity Match'] = df.apply(check_entity_match, axis=1)
    """  
    df = update_df_with_lambda(df, 'Context Entities', 
                               lambda row: extract_all_entities(row['Document']) 
                                if row.get('Context Entities') is None else row['Context Entities'])

    # Update or create 'Question Entities' column by applying entity extraction function if the value is NA
    df = update_df_with_lambda(df, 'Question Entities', 
                               lambda row: extract_all_entities(row['Question']) 
                               if row.get('Question Entities')is None else row['Question Entities'])

    # Update or create 'Answer Entities' column by applying entity extraction function if the value is NA
    df = update_df_with_lambda(df, 'Answer Entities', 
                               lambda row: extract_all_entities(row['Answer']) 
                               if row.get('Answer Entities') is None else row['Answer Entities'])

    # Update or create 'Entity Match' column by applying the check entity match function if the value is NA
    df = update_df_with_lambda(df, 'Entity Match', 
                               lambda row: check_entity_match(row) 
                               if row.get('Entity Match') is None else row['Entity Match'])
    """
    return df
# Out:
# /home/jovyan/.local/lib/python3.8/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11060). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# 2024-01-18 14:54:17.279287: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-18 14:54:17.407383: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-18 14:54:18.102758: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-18 14:54:18.102835: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-18 14:54:18.102840: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-18 14:54:32,718 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-PER, S-LOC, B-MISC, E-MISC, B-ORG, E-ORG, I-ORG, I-PER, B-LOC, I-LOC, E-LOC, I-MISC, <START>, <STOP>

# %%
def contains_desired_entity(entities_list):
    desired_types = {'Phone', 'Email'}
    return any(entity['entityType'] in desired_types for entity in entities_list)


def filterFactQuestions(df):
    df = extractEntities(df)
    return df[~((df['Question'].str.split().str.len() < 30) & df['Answer Entities'].apply(contains_desired_entity))]

def extract_desired_entities(entities_list):
    # Define the desired entity types
    desired_types = {'Phone', 'Email'}
    
    # Extract entities that match the desired types
    matching_entities = [entity for entity in entities_list if entity['entityType'] in desired_types]
    
    return matching_entities

# %%
def filterFactQuestionCorrectness(df):
    df['Answer Entities'] = df['Answer'].apply(extract_all_entities)
    # Apply a filter condition to each row
    #filtered_df = df[df.apply(lambda row: row["Fact"] in row["Answer Entities"], axis=1)]
    filtered_df = df[df.apply(lambda row: any( row["Fact"]['value'] == entity['value'] for entity in row["Answer Entities"]) if isinstance(row["Answer Entities"], list) else False, axis=1)]
    return filtered_df

# %% [markdown]
# #### LLM Scoring

# %%
from llm_filter import estimate_relevance

def llmScore(df):
    return update_df_with_lambda(df, 'LLM Score', lambda row: estimate_relevance(row['Question'], row['Document']))

# %% [markdown]
# # Run

# %%
import os

sample = loadData(fname, basepath)

df = pd.DataFrame(columns = sample.columns)



for i in tqdm(range(5), desc="Processing"):
    raw_file_path = f"{basepath}/output_raw_{i}_{fname}.csv"

    if os.path.exists(raw_file_path):
        # Load the file into a DataFrame if it exists
        print(f"Skipping generation: {i}")
        new_questions_df = pd.read_csv(raw_file_path)
    else:
        df_gen = sample[~sample['Document'].isin(df['Document'])]
        new_questions_df = generateQuestions(df_gen)
        if df_gen.empty:
            break
    new_questions_df.to_csv(raw_file_path)
    df = pd.concat([df, new_questions_df], ignore_index=True, sort=False)
    df = rougeFilter(df)
    df = vectorFilter(df)
    df = filterFactQuestions(df)
    df = llmScore(df)


## take top one for each doc
idx = df.groupby('Document')['LLM Score'].idxmax()
df = df.loc[idx]

df.to_csv(f"{basepath}/output_full_{fname}.csv")
df.to_csv(f"{basepath}/output_{fname}.csv", columns = ['topic_id', 'filename', 'header', 'section_text', 'Question', 'Answer'])
# Out:
# Processing:   0%|          | 0/5 [00:00<?, ?it/s]
# Generating QAs:   0%|          | 0/50 [00:00<?, ?it/s]
# Generating QAs:   2%|▏         | 1/50 [00:12<10:14, 12.54s/it]
# Generating QAs:   4%|▍         | 2/50 [00:26<10:36, 13.25s/it]
# Generating QAs:   6%|▌         | 3/50 [00:46<12:54, 16.48s/it]
# Generating QAs:   8%|▊         | 4/50 [01:05<13:23, 17.47s/it]
# Generating QAs:  10%|█         | 5/50 [01:17<11:35, 15.45s/it]
# Generating QAs:  12%|█▏        | 6/50 [01:31<11:05, 15.12s/it]
# Generating QAs:  14%|█▍        | 7/50 [01:42<09:51, 13.76s/it]
# Generating QAs:  16%|█▌        | 8/50 [01:58<09:59, 14.28s/it]
# Generating QAs:  18%|█▊        | 9/50 [02:18<10:55, 15.99s/it]
# Generating QAs:  20%|██        | 10/50 [02:30<09:59, 14.98s/it]
# Generating QAs:  22%|██▏       | 11/50 [02:58<12:18, 18.93s/it]
# Generating QAs:  24%|██▍       | 12/50 [03:19<12:25, 19.62s/it]
# Generating QAs:  26%|██▌       | 13/50 [03:45<13:11, 21.40s/it]
# Generating QAs:  28%|██▊       | 14/50 [04:01<11:48, 19.67s/it]
# Failed to generate QA for doc: 29: Enteroscopie distaal poliklinisch: Begeleiding na sedatie: - Voor zowel Midazolam sedatie als vo. Error: 'list' object has no attribute 'qa_list'
# Generating QAs:  30%|███       | 15/50 [04:20<11:27, 19.64s/it]
# Generating QAs:  32%|███▏      | 16/50 [04:32<09:44, 17.18s/it]
# Generating QAs:  34%|███▍      | 17/50 [04:45<08:48, 16.02s/it]
# Generating QAs:  36%|███▌      | 18/50 [05:13<10:28, 19.64s/it]
# Generating QAs:  38%|███▊      | 19/50 [05:28<09:26, 18.29s/it]
# Generating QAs:  40%|████      | 20/50 [05:55<10:30, 21.01s/it]
# Generating QAs:  42%|████▏     | 21/50 [06:14<09:49, 20.33s/it]
# Generating QAs:  44%|████▍     | 22/50 [06:31<08:56, 19.17s/it]
# Generating QAs:  46%|████▌     | 23/50 [06:51<08:48, 19.57s/it]
# Generating QAs:  48%|████▊     | 24/50 [07:14<08:53, 20.53s/it]
# Generating QAs:  50%|█████     | 25/50 [07:24<07:16, 17.47s/it]
# Generating QAs:  52%|█████▏    | 26/50 [07:38<06:34, 16.45s/it]
# Generating QAs:  54%|█████▍    | 27/50 [07:48<05:32, 14.47s/it]
# Generating QAs:  56%|█████▌    | 28/50 [08:00<05:01, 13.70s/it]
# Generating QAs:  58%|█████▊    | 29/50 [08:09<04:17, 12.28s/it]
# Generating QAs:  60%|██████    | 30/50 [08:18<03:48, 11.43s/it]
# Generating QAs:  62%|██████▏   | 31/50 [08:35<04:05, 12.90s/it]
# Generating QAs:  64%|██████▍   | 32/50 [08:49<03:57, 13.21s/it]
# Generating QAs:  66%|██████▌   | 33/50 [09:04<03:57, 13.96s/it]
# Generating QAs:  68%|██████▊   | 34/50 [09:38<05:15, 19.74s/it]
# Generating QAs:  70%|███████   | 35/50 [09:52<04:29, 17.99s/it]
# Generating QAs:  72%|███████▏  | 36/50 [10:10<04:15, 18.23s/it]
# Generating QAs:  74%|███████▍  | 37/50 [10:40<04:40, 21.60s/it]
# Generating QAs:  76%|███████▌  | 38/50 [10:59<04:11, 20.95s/it]
# Generating QAs:  78%|███████▊  | 39/50 [11:11<03:19, 18.18s/it]
# Generating QAs:  80%|████████  | 40/50 [11:25<02:47, 16.79s/it]
# Generating QAs:  82%|████████▏ | 41/50 [11:42<02:33, 17.01s/it]
# Generating QAs:  84%|████████▍ | 42/50 [11:50<01:54, 14.28s/it]
# Generating QAs:  86%|████████▌ | 43/50 [11:59<01:28, 12.70s/it]
# Generating QAs:  88%|████████▊ | 44/50 [12:20<01:30, 15.05s/it]
# Generating QAs:  90%|█████████ | 45/50 [12:31<01:10, 14.01s/it]
# Generating QAs:  92%|█████████▏| 46/50 [13:03<01:17, 19.28s/it]
# Generating QAs:  94%|█████████▍| 47/50 [13:14<00:50, 16.79s/it]
# Generating QAs:  96%|█████████▌| 48/50 [13:38<00:38, 19.16s/it]
# Generating QAs:  98%|█████████▊| 49/50 [13:48<00:16, 16.45s/it]
# Generating QAs: 100%|██████████| 50/50 [14:14<00:00, 17.08s/it]
# Processing:  20%|██        | 1/5 [19:04<1:16:18, 1144.51s/it]
# Generating QAs:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating QAs:  50%|█████     | 1/2 [00:14<00:14, 14.52s/it]
# Generating QAs: 100%|██████████| 2/2 [00:27<00:00, 13.76s/it]
# Processing:  40%|████      | 2/5 [21:16<27:26, 548.94s/it]
# Generating QAs:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating QAs: 100%|██████████| 1/1 [00:14<00:00, 14.02s/it]
# Processing:  60%|██████    | 3/5 [23:05<11:36, 348.23s/it]
# Generating QAs:   0%|          | 0/1 [00:00<?, ?it/s]
# Generating QAs: 100%|██████████| 1/1 [00:18<00:00, 18.54s/it]
# Processing:  80%|████████  | 4/5 [26:07<04:42, 282.33s/it]
# Generating QAs: 0it [00:00, ?it/s]
# Processing:  80%|████████  | 4/5 [26:07<06:31, 391.81s/it]

# %% [markdown]
# ## Export Q&A Pairs

# %%
df.to_csv(f"{basepath}/output_full_{fname}.csv")
df.to_csv(f"{basepath}/output_{fname}.csv", columns = ['topic_id', 'filename', 'header', 'section_text', 'Question', 'Answer'])

# %%
df
# Out:
#     topic_id                                           filename  \
# 44        10                             Anesthesie volwassenen
# 127       10     Septumcorrectie (operatie aan neustussenschot)
# 97        11                             Anesthesie volwassenen
# 96        13                        Azathioprine (reumatologie)
# 131       13                                  Botox (ZGT Helon)
# 105       14                                          Epoxyhars
# 133       14                                       Formaldehyde
# 55        15                                Aftercare (Nocepta)
# 15        16                          Lymfoedeem, fysiotherapie
# 135       17                             Anesthesie volwassenen
# 6         18                   Flash Glucose Monitoring Systeem
# 138       18                   Insulinepomptherapie (Patchpomp)
# 139       18                   Insulinepomptherapie (Patchpomp)
# 36        19     Borstverkleining, borstlift, borstversteviging
# 57         1                                      Beenamputatie
# 120        1             Dik vloeibare voeding bij slikklachten
# 112        1     Koolhydraatbeperkt dieet bij diabetes mellitus
# 119        1     Koolhydraatbeperkt dieet bij diabetes mellitus
# 111        1                     Voedingsadviezen bij MCT-dieet
# 122        1          Voedingsadviezen bij lactose intolerantie
# 17        20                        Caelyx, patiënteninformatie
# 61        22                                  Collagene colitis
# 144       22                 Ulcus, oncologische, verzorgen van
# 107       23                                          Chalazion
# 147       23  Druppelen met Atropine (0,05%), bij kinderen v...
# 19        24                                Aftercare (Nocepta)
# 151       24                                    Pijn bij kanker
# 84        25                             Anesthesie volwassenen
# 49        29                  Enteroscopie distaal poliklinisch
# 73        30                                          Epoxyhars
# 89        33                                              Shunt
# 165       34                        Caelyx, patiënteninformatie
# 0         35                  Enteroscopie distaal poliklinisch
# 110       36           Endo-echografie via de luchtwegen (EBUS)
# 63        37   Methotrexaat (MTX), instructie zelftoedienen van
# 41        39       Carboplatin_Gemcitabine, patiënteninformatie
# 31        41                     Azathioprine (longgeneeskunde)
# 82        42                        Azathioprine (reumatologie)
# 156       43                                  Collagene colitis
# 52        45                        Azathioprine (reumatologie)
# 66        50         Mohs' micrografische chirurgie (Isala_ZGT)
# 28        51                               Upadacitinib bij IBD
# 26         5                             Anesthesie volwassenen
# 123        5                   Osteosynthesemateriaal inbrengen
# 80        60                                      Beenamputatie
# 13         6     Borstverkleining, borstlift, borstversteviging
# 125        6                                    Pijn bij kanker
# 94         9     Borstverkleining, borstlift, borstversteviging
# 126        9  Medische tatoeage en permanente make-up (ZGT H...
#
#                                                 header  \
# 44                               Vormen van anesthesie
# 127                         Wat is het neustussenschot
# 97                   Eten en drinken voor de operatie.
# 96                              Mogelijke bijwerkingen
# 131                                  Andere indicaties
# 105   Wat zijn de reacties bij een epoxyhars allergie?
# 133              Behandeling van de contact dermatitis
# 55                                           Medicatie
# 15                                             Bewegen
# 135                               De dag van de opname
# 6                     Flash Glucose Monitoring Systeem
# 138                                  Lage bloedsuikers
# 139                                Vervolgtraject pomp
# 36                           Oefeningen in week 1 en 2
# 57                                           Diëtetiek
# 120                          Voorbeeld van een dagmenu
# 112                                        Dieetadvies
# 119                              Variatiemogelijkheden
# 111                                        Nagerechten
# 122                                 Sauzen, kruiden en
# 17                             C Wijze van toediening:
# 61                                             Oorzaak
# 144                             Risico’s/ complicaties
# 107                                          Chalazion
# 147                                   Gebruik atropine
# 19                                           Aftercare
# 151                               Wat u zelf kunt doen
# 84                        Instructies vóór de operatie
# 49                              Begeleiding na sedatie
# 73   14. Epoxyhars Wat is epoxyhars en waar vind je...
# 89                                      Het aansluiten
# 165                     Het verloop van de Caelyx kuur
# 0                                        Voorbereiding
# 110                             Duur van het onderzoek
# 63                                  MTX en vaccinaties
# 41   Naast de algemene bijwerkingen kunnen de volge...
# 31                                       Voorbereiding
# 82                                   Wijze van innemen
# 156                                  Collagene colitis
# 52                                        Azathioprine
# 66                          Verloop van de behandeling
# 28          Upadacitinib bij inflammatoire darmziekten
# 26                                            Uw gebit
# 123          Wat is een fractuur en wat merkt u ervan?
# 80                                           Leefstijl
# 13                          Borstverkleining/borstlift
# 125                                 Hormonale therapie
# 94                                           Littekens
# 126                                     Eerste gesprek
#
#                                           section_text  \
# 44   Algehele anesthesie (narcose) Bij deze vorm va...
# 127  Het neustussenschot (neusseptum of kortweg sep...
# 97   Voor uw veiligheid dient u nuchter te zijn voo...
# 96   Bijwerkingen kunnen optreden. Meest voorkomend...
# 131  Niet alleen rimpels kunnen behandeld worden me...
# 105  De reactie uit zich in een typische allergisch...
# 133  Probeer formaldehyde te vermijden, of neem maa...
# 55   - Verdovingsvloeistof. De verdovingsvloeistof ...
# 15   Probeer de Nederlandse Norm Gezond Bewegen te ...
# 135  Op de operatiedag krijgt u operatiekleding aan...
# 6    U heeft goedkeuring gekregen voor het gebruik ...
# 138  Bij lage bloedsuikers proberen de oorzaak van ...
# 139  Het diabetesteam beoordeelt of verlenging pomp...
# 36   Figuur 2. Beweeg uw arm gestrekt voorwaarts. G...
# 57   Wie ziek is en/of een operatie moet ondergaan,...
# 120  Ontbijt: \n- pap, eventueel met suiker en/of r...
# 112  Voeding bestaat uit drie hoofdbestanddelen: ei...
# 119  Het persoonlijke voedingsadvies dat u van de d...
# 111  Magere vlasoorten, magere yoghurt, magere kwar...
# 122  specerijen Sauzen, aroma’s, ketjapsoorten en j...
# 17   De medicijnen worden u toegediend via een infu...
# 61   De oorzaak van collagene colitis is nog niet b...
# 144  Wondvocht Het ulcus kan vocht produceren waard...
# 107  Uw oogarts heeft u verwezen voor het laten ver...
# 147  De druppels moeten elke avond voor het slapen ...
# 19   Vandaag heeft u een behandeling ondergaan om u...
# 151  Er is geen standaardmanier om met pijn om te g...
# 84   Binnenkort ondergaat u een operatie in de ZGT....
# 49   - Voor zowel Midazolam sedatie als voor Propof...
# 73   Epoxyhars is een chemisch product, dat deel ui...
# 89   Om te kunnen dialyseren moet de shunt worden a...
# 165  U begint met een chemokuurkuur. Deze kuur best...
# 0    Een week voor het onderzoek mag u geen ijzerta...
# 110  De voorbereidingen nemen ongeveer een kwartier...
# 63   Het gebruik van MTX in combinatie met een vacc...
# 41   - Bij koorts boven de 38,5° moet u contact met...
# 31   Bloedcontrole voor gebruik Voorafgaand aan de ...
# 82   Azathioprine is een medicijn in de vorm van ta...
# 156  Collagene colitis is een ontstekingsziekte van...
# 52   Uw reumatoloog heeft azathioprine voorgeschrev...
# 66   De ingreep wordt uitgevoerd onder plaatselijke...
# 28   Uw behandelend medisch specialist of verpleegk...
# 26   Ondanks alle zorgvuldigheid kan in zeldzame ge...
# 123  We spreken van een fractuur wanneer een bot ge...
# 80   Roken Door nicotine trekken bloedvaten samen e...
# 13   Zware of slappe borsten kunnen zowel psychisch...
# 125  Bij verspreid voorkomende, pijnlijke uitzaaiin...
# 94   Na de operatie zijn uw borsten kleiner en stev...
# 126  Tijdens een eerste gesprek worden uw wensen be...
#
#                                               Document  \
# 44   10: Anesthesie volwassenen: Vormen van anesthe...
# 127  10: Septumcorrectie (operatie aan neustussensc...
# 97   11: Anesthesie volwassenen: Eten en drinken vo...
# 96   13: Azathioprine (reumatologie): Mogelijke bij...
# 131  13: Botox (ZGT Helon): Andere indicaties: Niet...
# 105  14: Epoxyhars: Wat zijn de reacties bij een ep...
# 133  14: Formaldehyde: Behandeling van de contact d...
# 55   15: Aftercare (Nocepta): Medicatie: - Verdovin...
# 15   16: Lymfoedeem, fysiotherapie: Bewegen: Probee...
# 135  17: Anesthesie volwassenen: De dag van de opna...
# 6    18: Flash Glucose Monitoring Systeem: Flash Gl...
# 138  18: Insulinepomptherapie (Patchpomp): Lage blo...
# 139  18: Insulinepomptherapie (Patchpomp): Vervolgt...
# 36   19: Borstverkleining, borstlift, borstverstevi...
# 57   1: Beenamputatie: Diëtetiek: Wie ziek is en/of...
# 120  1: Dik vloeibare voeding bij slikklachten: Voo...
# 112  1: Koolhydraatbeperkt dieet bij diabetes melli...
# 119  1: Koolhydraatbeperkt dieet bij diabetes melli...
# 111  1: Voedingsadviezen bij MCT-dieet: Nagerechten...
# 122  1: Voedingsadviezen bij lactose intolerantie: ...
# 17   20: Caelyx, patiënteninformatie: C Wijze van t...
# 61   22: Collagene colitis: Oorzaak: De oorzaak van...
# 144  22: Ulcus, oncologische, verzorgen van: Risico...
# 107  23: Chalazion: Chalazion: Uw oogarts heeft u v...
# 147  23: Druppelen met Atropine (0,05%), bij kinder...
# 19   24: Aftercare (Nocepta): Aftercare: Vandaag he...
# 151  24: Pijn bij kanker: Wat u zelf kunt doen: Er ...
# 84   25: Anesthesie volwassenen: Instructies vóór d...
# 49   29: Enteroscopie distaal poliklinisch: Begelei...
# 73   30: Epoxyhars: 14. Epoxyhars Wat is epoxyhars ...
# 89   33: Shunt: Het aansluiten: Om te kunnen dialys...
# 165  34: Caelyx, patiënteninformatie: Het verloop v...
# 0    35: Enteroscopie distaal poliklinisch: Voorber...
# 110  36: Endo-echografie via de luchtwegen (EBUS): ...
# 63   37: Methotrexaat (MTX), instructie zelftoedien...
# 41   39: Carboplatin_Gemcitabine, patiënteninformat...
# 31   41: Azathioprine (longgeneeskunde): Voorbereid...
# 82   42: Azathioprine (reumatologie): Wijze van inn...
# 156  43: Collagene colitis: Collagene colitis: Coll...
# 52   45: Azathioprine (reumatologie): Azathioprine:...
# 66   50: Mohs' micrografische chirurgie (Isala_ZGT)...
# 28   51: Upadacitinib bij IBD: Upadacitinib bij inf...
# 26   5: Anesthesie volwassenen: Uw gebit: Ondanks a...
# 123  5: Osteosynthesemateriaal inbrengen: Wat is ee...
# 80   60: Beenamputatie: Leefstijl: Roken Door nicot...
# 13   6: Borstverkleining, borstlift, borstverstevig...
# 125  6: Pijn bij kanker: Hormonale therapie: Bij ve...
# 94   9: Borstverkleining, borstlift, borstverstevig...
# 126  9: Medische tatoeage en permanente make-up (ZG...
#
#                                               Question  \
# 44   Wat is het verschil tussen algehele en regiona...
# 127                        Wat is het neustussenschot?
# 97    Hoe lang moet ik nuchter zijn voor een operatie?
# 96   Hoe vaak komen maag- en darmklachten voor bij ...
# 131  Welke indicaties kunnen behandeld worden met b...
# 105  Hoe kan huidcontact met verharders worden beha...
# 133  Wat is de behandeling voor contact dermatitis ...
# 55   Wat zijn mogelijke bijwerkingen van de ontstek...
# 15   Wat wordt verstaan onder matig intensieve lich...
# 135  Moet ik mijn operatiekleding zelf meenemen of ...
# 6         Wat is een Flash Glucose Monitoring Systeem?
# 138  Welke rol spelen hormonale veranderingen (mens...
# 139  Op welke punten beoordeelt het diabetesteam of...
# 36   Wat zijn de aanbevolen oefeningen voor de eers...
# 57   Waarom is het belangrijk om goed op de voeding...
# 120  Wat is een voorbeeld van een ontbijt voor pati...
# 112  Welke drie hoofdbestanddelen bestaan er in voe...
# 119  Welke suggesties en variaties kunnen worden ge...
# 111  Welke voedingsmiddelen zijn toegestaan bij een...
# 122  Welke soorten kruiden en specerijen zijn toege...
# 17   Wat moet ik doen bij het ervaren van bijwerkin...
# 61            Wat is de oorzaak van collagene colitis?
# 144  Wat kan er gedaan worden om geur te voorkomen ...
# 107                              Wat is een chalazion?
# 147  Is het nodig om beide ogen te druppelen als he...
# 19   Wat is de reden voor de behandeling die ik van...
# 151  Wat zijn enkele suggesties om met pijn om te g...
# 84   Wat is de betekenis van anesthesie en waarom i...
# 49   Moet ik begeleiding regelen voor na de behande...
# 73   Kunnen de stoffen in epoxyhars een allergische...
# 89   Waarom moeten er twee naalden worden gebruikt ...
# 165  Wat is de naam van de chemokuurkuur die wordt ...
# 0                             Wat is een enteroscopie?
# 110  Hoe lang duurt de voorbereiding van een endo-e...
# 63   Kan ik Methotrexaat gebruiken in combinatie me...
# 41   Wat moet ik doen als ik koorts krijg boven de ...
# 31   Waarom wordt er voorafgaand aan de start van d...
# 82   Wat moet er worden gedaan als de inname van Az...
# 156                   Is collagene colitis te genezen?
# 52   Wat is azathioprine en waar wordt het voor voo...
# 66               Wat is het verloop van de behandeling
# 28                                Wat is Upadacitinib?
# 26   Welke specifieke afwijkingen moet u melden bij...
# 123  Wat is een fractuur en hoe wordt het gedefinie...
# 80   Hoe beïnvloedt roken de genezing van een wond ...
# 13   Welke oplossing kan een verkleinende operatie ...
# 125              Wat is hormonale therapie bij kanker?
# 94   Welke cremes kunnen gebruikt worden om de litt...
# 126  Wat wordt er besproken tijdens het eerste gesp...
#
#                                                 Answer  \
# 44   Het verschil tussen algehele en regionale anes...
# 127  Het neustussenschot (neusseptum of kortweg sep...
# 97   Voor uw veiligheid dient u nuchter te zijn voo...
# 96   Maag- en darmklachten komen vaak voor bij het ...
# 131  Botuline-toxine kan gebruikt worden voor de be...
# 105  Bij huidcontact met verharders moeten de huid ...
# 133  De behandeling voor contact dermatitis veroorz...
# 55   De ontstekingsremmer kan een aantal bijwerking...
# 15   Matig intensieve lichamelijke activiteit voor ...
# 135    Op de operatiedag krijgt u operatiekleding aan.
# 6    Een Flash Glucose Monitoring Systeem (FGM) is ...
# 138  Hormonale veranderingen, zoals tijdens de mens...
# 139  Het diabetesteam beoordeelt op drie punten of ...
# 36   De aanbevolen oefeningen voor de eerste en twe...
# 57   Tijdens en na een operatie heeft het lichaam m...
# 120  Een voorbeeld van een ontbijt voor patiënten m...
# 112  Voeding bestaat uit drie hoofdbestanddelen: ei...
# 119  De onderstaande suggesties en variaties kunnen...
# 111  - Nagerechten: Magere vlasoorten, magere yoghu...
# 122  Alle kruiden en specerijen zijn toegestaan bij...
# 17   Als u klachten krijgt die u niet vertrouwt, ku...
# 61   De oorzaak van collagene colitis is nog niet b...
# 144  Om geur te voorkomen, dient het ulcus goed ger...
# 107  Een chalazion is een zwelling of bultje dat on...
# 147  Nee, als uw kind maar aan één oog myopie heeft...
# 19   De behandeling die u vandaag heeft ondergaan h...
# 151  Enkele suggesties om met pijn om te gaan bij k...
# 84   Anesthesie is een vorm van verdoving die nodig...
# 49   Ja, u moet begeleiding regelen voor na de beha...
# 73   Ja, elk van deze stoffen kunnen een irriterend...
# 89   Er worden twee naalden gebruikt omdat één naal...
# 165  De chemokuurkuur die wordt gebruikt in de Cael...
# 0    Een enteroscopie is een onderzoek waarbij de b...
# 110  De voorbereidingen nemen ongeveer een kwartier...
# 63   Ja, het gebruik van Methotrexaat in combinatie...
# 41   Bij koorts boven de 38,5° moet u contact met o...
# 31   Dit wordt gedaan om te bepalen of er een afwij...
# 82   Als de inname van Azathioprine wordt vergeten,...
# 156  Collagene colitis is een chronische aandoening...
# 52   Azathioprine is een klassieke reumaremmer die ...
# 66   De ingreep wordt uitgevoerd onder plaatselijke...
# 28   Upadacitinib is een medicijn dat wordt gebruik...
# 26   U moet afwijkingen zoals loszittende tanden of...
# 123  Een fractuur is een gebroken bot. Het kan een ...
# 80   Nicotine zorgt voor samentrekking van bloedvat...
# 13   Een verkleinende operatie kan een oplossing bi...
# 125  Hormonale therapie kan verlichting geven bij v...
# 94   Als de wonden goed zijn genezen, kunt u deze m...
# 126  Tijdens het eerste gesprek worden uw wensen be...
#
#                                 Question-Context ROUGE  \
# 44   [{'rouge-1': {'r': 0.03333333333333333, 'p': 0...
# 127  [{'rouge-1': {'r': 0.03896103896103896, 'p': 0...
# 97   [{'rouge-1': {'r': 0.07142857142857142, 'p': 0...
# 96   [{'rouge-1': {'r': 0.06060606060606061, 'p': 0...
# 131  [{'rouge-1': {'r': 0.09523809523809523, 'p': 0...
# 105  [{'rouge-1': {'r': 0.058823529411764705, 'p': ...
# 133  [{'rouge-1': {'r': 0.1, 'p': 0.3, 'f': 0.14999...
# 55   [{'rouge-1': {'r': 0.034482758620689655, 'p': ...
# 15   [{'rouge-1': {'r': 0.08620689655172414, 'p': 0...
# 135  [{'rouge-1': {'r': 0.018518518518518517, 'p': ...
# 6    [{'rouge-1': {'r': 0.052083333333333336, 'p': ...
# 138  [{'rouge-1': {'r': 0.046511627906976744, 'p': ...
# 139  [{'rouge-1': {'r': 0.19047619047619047, 'p': 0...
# 36   [{'rouge-1': {'r': 0.05747126436781609, 'p': 0...
# 57   [{'rouge-1': {'r': 0.10416666666666667, 'p': 0...
# 120  [{'rouge-1': {'r': 0.20833333333333334, 'p': 0...
# 112  [{'rouge-1': {'r': 0.03731343283582089, 'p': 0...
# 119  [{'rouge-1': {'r': 0.28125, 'p': 0.81818181818...
# 111  [{'rouge-1': {'r': 0.006097560975609756, 'p': ...
# 122  [{'rouge-1': {'r': 0.125, 'p': 0.6, 'f': 0.206...
# 17   [{'rouge-1': {'r': 0.030120481927710843, 'p': ...
# 61   [{'rouge-1': {'r': 0.08196721311475409, 'p': 0...
# 144  [{'rouge-1': {'r': 0.05555555555555555, 'p': 0...
# 107  [{'rouge-1': {'r': 0.047619047619047616, 'p': ...
# 147  [{'rouge-1': {'r': 0.09016393442622951, 'p': 0...
# 19   [{'rouge-1': {'r': 0.12903225806451613, 'p': 0...
# 151  [{'rouge-1': {'r': 0.0625, 'p': 0.727272727272...
# 84   [{'rouge-1': {'r': 0.16363636363636364, 'p': 0...
# 49   [{'rouge-1': {'r': 0.03508771929824561, 'p': 0...
# 73   [{'rouge-1': {'r': 0.07894736842105263, 'p': 0...
# 89   [{'rouge-1': {'r': 0.14545454545454545, 'p': 0...
# 165  [{'rouge-1': {'r': 0.19047619047619047, 'p': 0...
# 0    [{'rouge-1': {'r': 0.020202020202020204, 'p': ...
# 110  [{'rouge-1': {'r': 0.13333333333333333, 'p': 0...
# 63   [{'rouge-1': {'r': 0.13513513513513514, 'p': 0...
# 41   [{'rouge-1': {'r': 0.061946902654867256, 'p': ...
# 31   [{'rouge-1': {'r': 0.1188118811881188, 'p': 0....
# 82   [{'rouge-1': {'r': 0.058823529411764705, 'p': ...
# 156  [{'rouge-1': {'r': 0.1, 'p': 0.4, 'f': 0.15999...
# 52   [{'rouge-1': {'r': 0.09090909090909091, 'p': 0...
# 66   [{'rouge-1': {'r': 0.031496062992125984, 'p': ...
# 28   [{'rouge-1': {'r': 0.018518518518518517, 'p': ...
# 26   [{'rouge-1': {'r': 0.09302325581395349, 'p': 0...
# 123  [{'rouge-1': {'r': 0.10909090909090909, 'p': 0...
# 80   [{'rouge-1': {'r': 0.04697986577181208, 'p': 0...
# 13   [{'rouge-1': {'r': 0.1518987341772152, 'p': 0....
# 125  [{'rouge-1': {'r': 0.04, 'p': 0.16666666666666...
# 94   [{'rouge-1': {'r': 0.075, 'p': 0.5454545454545...
# 126  [{'rouge-1': {'r': 0.18867924528301888, 'p': 0...
#
#                                   Answer-Context ROUGE  \
# 44   [{'rouge-1': {'r': 0.12666666666666668, 'p': 0...
# 127  [{'rouge-1': {'r': 0.22077922077922077, 'p': 1...
# 97   [{'rouge-1': {'r': 0.24285714285714285, 'p': 1...
# 96   [{'rouge-1': {'r': 0.09090909090909091, 'p': 0...
# 131  [{'rouge-1': {'r': 0.21428571428571427, 'p': 0...
# 105  [{'rouge-1': {'r': 0.1323529411764706, 'p': 0....
# 133  [{'rouge-1': {'r': 0.4, 'p': 0.5, 'f': 0.44444...
# 55   [{'rouge-1': {'r': 0.12643678160919541, 'p': 0...
# 15   [{'rouge-1': {'r': 0.29310344827586204, 'p': 1...
# 135  [{'rouge-1': {'r': 0.12962962962962962, 'p': 1...
# 6    [{'rouge-1': {'r': 0.19791666666666666, 'p': 0...
# 138  [{'rouge-1': {'r': 0.13953488372093023, 'p': 0...
# 139  [{'rouge-1': {'r': 0.23809523809523808, 'p': 0...
# 36   [{'rouge-1': {'r': 0.42528735632183906, 'p': 0...
# 57   [{'rouge-1': {'r': 0.17708333333333334, 'p': 0...
# 120  [{'rouge-1': {'r': 0.6666666666666666, 'p': 0....
# 112  [{'rouge-1': {'r': 0.23880597014925373, 'p': 1...
# 119  [{'rouge-1': {'r': 0.375, 'p': 1.0, 'f': 0.545...
# 111  [{'rouge-1': {'r': 0.49390243902439024, 'p': 0...
# 122  [{'rouge-1': {'r': 0.125, 'p': 0.6666666666666...
# 17   [{'rouge-1': {'r': 0.09036144578313253, 'p': 0...
# 61   [{'rouge-1': {'r': 0.2459016393442623, 'p': 1....
# 144  [{'rouge-1': {'r': 0.1527777777777778, 'p': 0....
# 107  [{'rouge-1': {'r': 0.14285714285714285, 'p': 0...
# 147  [{'rouge-1': {'r': 0.09836065573770492, 'p': 0...
# 19   [{'rouge-1': {'r': 0.2903225806451613, 'p': 0....
# 151  [{'rouge-1': {'r': 0.1875, 'p': 0.489795918367...
# 84   [{'rouge-1': {'r': 0.18181818181818182, 'p': 0...
# 49   [{'rouge-1': {'r': 0.09649122807017543, 'p': 0...
# 73   [{'rouge-1': {'r': 0.08771929824561403, 'p': 0...
# 89   [{'rouge-1': {'r': 0.2727272727272727, 'p': 0....
# 165  [{'rouge-1': {'r': 0.19047619047619047, 'p': 0...
# 0    [{'rouge-1': {'r': 0.09090909090909091, 'p': 0...
# 110  [{'rouge-1': {'r': 0.17777777777777778, 'p': 1...
# 63   [{'rouge-1': {'r': 0.3783783783783784, 'p': 0....
# 41   [{'rouge-1': {'r': 0.09734513274336283, 'p': 1...
# 31   [{'rouge-1': {'r': 0.15841584158415842, 'p': 0...
# 82   [{'rouge-1': {'r': 0.19117647058823528, 'p': 0...
# 156  [{'rouge-1': {'r': 0.25, 'p': 0.22727272727272...
# 52   [{'rouge-1': {'r': 0.25, 'p': 0.78571428571428...
# 66   [{'rouge-1': {'r': 0.9448818897637795, 'p': 1....
# 28   [{'rouge-1': {'r': 0.16666666666666666, 'p': 0...
# 26   [{'rouge-1': {'r': 0.16279069767441862, 'p': 0...
# 123  [{'rouge-1': {'r': 0.2545454545454545, 'p': 0....
# 80   [{'rouge-1': {'r': 0.08053691275167785, 'p': 0...
# 13   [{'rouge-1': {'r': 0.20253164556962025, 'p': 0...
# 125  [{'rouge-1': {'r': 0.56, 'p': 0.82352941176470...
# 94   [{'rouge-1': {'r': 0.4, 'p': 0.969696969696969...
# 126  [{'rouge-1': {'r': 0.4528301886792453, 'p': 0....
#
#      Question-Context ROUGE-L F1  Answer-Context ROUGE-L F1  \
# 44                      0.062893                   0.217143
# 127                     0.074074                   0.361702
# 97                      0.126582                   0.390805
# 96                      0.102564                   0.155844
# 131                     0.163265                   0.305085
# 105                     0.080000                   0.200000
# 133                     0.150000                   0.333333
# 55                      0.063830                   0.215686
# 15                      0.147059                   0.426667
# 135                     0.031250                   0.229508
# 6                       0.097087                   0.285714
# 138                     0.076923                   0.169492
# 139                     0.254545                   0.363636
# 36                      0.058252                   0.453333
# 57                      0.160714                   0.264463
# 120                     0.150000                   0.528302
# 112                     0.068493                   0.385542
# 119                     0.418605                   0.545455
# 111                     0.011696                   0.634921
# 122                     0.172414                   0.175439
# 17                      0.044944                   0.163934
# 61                      0.147059                   0.394737
# 144                     0.102564                   0.260355
# 107                     0.080000                   0.111111
# 147                     0.159420                   0.176471
# 19                      0.190476                   0.355556
# 151                     0.100719                   0.248588
# 84                      0.228571                   0.246575
# 49                      0.065574                   0.155039
# 73                      0.128000                   0.158730
# 89                      0.235294                   0.410959
# 165                     0.242424                   0.193548
# 0                       0.038835                   0.156522
# 110                     0.140351                   0.301887
# 63                      0.217391                   0.472727
# 41                      0.078125                   0.177419
# 31                      0.188034                   0.238095
# 82                      0.075000                   0.269663
# 156                     0.160000                   0.238095
# 52                      0.150943                   0.379310
# 66                      0.059701                   0.971660
# 28                      0.035088                   0.213333
# 26                      0.115385                   0.254545
# 123                     0.187500                   0.285714
# 80                      0.088050                   0.131737
# 13                      0.172043                   0.228571
# 125                     0.064516                   0.523810
# 94                      0.131868                   0.566372
# 126                     0.179104                   0.525000
#
#                                              Embedding  \
# 44   [0.022561257416644272, 0.0007618076489396394, ...
# 127  [-0.005245539726644542, -0.014108693282673543,...
# 97   [0.006605985727322925, -0.03711994934170077, 0...
# 96   [0.005589070069189393, -0.030945203118361214, ...
# 131  [-0.0030785119180306996, -0.0232077315595189, ...
# 105  [0.02238983736009096, -0.012224410984802246, 0...
# 133  [0.020079466654988606, -0.013833082667701904, ...
# 55   [-0.01583096234668532, -0.0333633840205851, 0....
# 15   [0.014031632256061398, -0.02711931882815061, 0...
# 135  [0.008764605165415593, -0.04564820668966094, 0...
# 6    [-0.007861022925124106, -0.018910162361741, 0....
# 138  [-0.011117709641463603, -0.04608979768794726, ...
# 139  [0.003458512637986617, -0.03337613271882451, 0...
# 36   [-0.03929128857073767, -0.03147377137235164, 0...
# 57   [0.014907062426195735, -0.031424379660894355, ...
# 120  [0.012065677296980132, -0.018015522994644994, ...
# 112  [0.015159823603250265, -0.013067984541838874, ...
# 119  [0.00841302814842333, -0.029859251037607802, 0...
# 111  [0.003104124733301375, -0.03679240829504692, 0...
# 122  [0.02502534271052202, -0.01996446522373796, 0....
# 17   [-0.008240059647451432, -0.044645907583664234,...
# 61   [0.002863027125300763, -0.02429079436406466, 0...
# 144  [0.024935720289044377, -0.0058849569870850224,...
# 107  [0.011506016302120883, -0.013227083646621432, ...
# 147  [0.003271064094431035, 0.002393156575469792, 0...
# 19   [0.010709849940569446, -0.02049922536708462, 0...
# 151  [0.019899791283728145, -0.03432304070151626, 0...
# 84   [0.004855427713803412, -0.019605678721953314, ...
# 49   [0.00023453328800537485, -0.030780911166045075...
# 73   [0.005936986518384261, -0.01996634258248021, 0...
# 89   [0.011506358299208055, -0.013812684619251598, ...
# 165  [0.007102624384045681, -0.020542585332883424, ...
# 0    [0.008796541137119012, -0.012134281726207665, ...
# 110  [-0.006087011639863309, -0.00550729644515972, ...
# 63   [-0.015144698326785631, -0.013261221237763693,...
# 41   [-0.003791754169146593, -0.02683197173015844, ...
# 31   [0.005607418445179471, -0.03675102637566464, 0...
# 82   [-0.011571077343162152, -0.03252687224601894, ...
# 156  [-0.021168244381766285, 0.0010298664845216606,...
# 52   [0.0006477603359375787, -0.02753653583659864, ...
# 66   [0.0022015194797368244, -0.027078217373643142,...
# 28   [-0.014305617609603716, -0.01408168016600819, ...
# 26   [0.005738650761907081, -0.00884214320918996, 0...
# 123  [0.025160270285533092, -0.018762950207453607, ...
# 80   [0.00570433653753024, -0.015680472577215845, 0...
# 13   [-0.01160230038743778, -0.003669654832602751, ...
# 125  [-0.014447044750711572, -0.02668881633904762, ...
# 94   [0.006052739097328193, -0.016012740312973114, ...
# 126  [0.020598232731116235, -0.0044447830208503075,...
#
#                                       Context Entities  \
# 44           [{'entityType': 'MISC', 'value': 'iPod'}]
# 127                                                 []
# 97                                                  []
# 96                                                  []
# 131  [{'entityType': 'MISC', 'value': 'Botox'}, {'e...
# 105                                                 []
# 133                                                 []
# 55         [{'entityType': 'ORG', 'value': 'Nocepta'}]
# 15   [{'entityType': 'MISC', 'value': 'Nederlandse ...
# 135                                                 []
# 6    [{'entityType': 'MISC', 'value': 'Flash Glucos...
# 138     [{'entityType': 'MISC', 'value': 'Patchpomp'}]
# 139     [{'entityType': 'MISC', 'value': 'Patchpomp'}]
# 36               [{'entityType': 'PER', 'value': 'O'}]
# 57                                                  []
# 120                                                 []
# 112                                                 []
# 119                                                 []
# 111  [{'entityType': 'MISC', 'value': 'MCT-dieet'},...
# 122                                                 []
# 17   [{'entityType': 'MISC', 'value': 'Caelyx'}, {'...
# 61   [{'entityType': 'PER', 'value': 'Sjögren'}, {'...
# 144                                                 []
# 107  [{'entityType': 'PER', 'value': 'Chalazion'}, ...
# 147      [{'entityType': 'MISC', 'value': 'Atropine'}]
# 19         [{'entityType': 'ORG', 'value': 'Nocepta'}]
# 151                                                 []
# 84             [{'entityType': 'LOC', 'value': 'ZGT'}]
# 49   [{'entityType': 'MISC', 'value': 'Midazolam'},...
# 73   [{'entityType': 'MISC', 'value': 'A'}, {'entit...
# 89                                                  []
# 165  [{'entityType': 'MISC', 'value': 'Caelyx'}, {'...
# 0                                                   []
# 110          [{'entityType': 'MISC', 'value': 'EBUS'}]
# 63   [{'entityType': 'MISC', 'value': 'Methotrexaat...
# 41   [{'entityType': 'MISC', 'value': 'Carboplatin'...
# 31   [{'entityType': 'MISC', 'value': 'TPMT-gen'}, ...
# 82                                                  []
# 156                                                 []
# 52                                                  []
# 66   [{'entityType': 'MISC', 'value': 'Mohs''}, {'e...
# 28   [{'entityType': 'MISC', 'value': 'Upadacitinib...
# 26                                                  []
# 123                                                 []
# 80   [{'entityType': 'MISC', 'value': 'Nederlandse ...
# 13                                                  []
# 125                                                 []
# 94                                                  []
# 126      [{'entityType': 'PER', 'value': 'ZGT Helon'}]
#
#                                      Question Entities  \
# 44                                                  []
# 127                                                 []
# 97                                                  []
# 96   [{'entityType': 'MISC', 'value': 'Azathioprine'}]
# 131                                                 []
# 105                                                 []
# 133                                                 []
# 55                                                  []
# 15                                                  []
# 135                                                 []
# 6    [{'entityType': 'MISC', 'value': 'Flash Glucos...
# 138                                                 []
# 139                                                 []
# 36                                                  []
# 57                                                  []
# 120                                                 []
# 112                                                 []
# 119                                                 []
# 111     [{'entityType': 'MISC', 'value': 'MCT-dieet'}]
# 122                                                 []
# 17          [{'entityType': 'ORG', 'value': 'Caelyx'}]
# 61                                                  []
# 144                                                 []
# 107                                                 []
# 147                                                 []
# 19                                                  []
# 151                                                 []
# 84             [{'entityType': 'LOC', 'value': 'ZGT'}]
# 49                                                  []
# 73                                                  []
# 89                                                  []
# 165        [{'entityType': 'MISC', 'value': 'Caelyx'}]
# 0                                                   []
# 110          [{'entityType': 'MISC', 'value': 'EBUS'}]
# 63   [{'entityType': 'MISC', 'value': 'Methotrexaat'}]
# 41   [{'entityType': 'MISC', 'value': 'Carboplatin'...
# 31       [{'entityType': 'MISC', 'value': 'TPMT-gen'}]
# 82   [{'entityType': 'MISC', 'value': 'Azathioprine'}]
# 156                                                 []
# 52                                                  []
# 66                                                  []
# 28   [{'entityType': 'MISC', 'value': 'Upadacitinib'}]
# 26                                                  []
# 123                                                 []
# 80                                                  []
# 13                                                  []
# 125                                                 []
# 94                                                  []
# 126                                                 []
#
#                                        Answer Entities  Entity Match  \
# 44                                                  []          True
# 127                                                 []          True
# 97                                                  []          True
# 96   [{'entityType': 'MISC', 'value': 'Azathioprine'}]         False
# 131  [{'entityType': 'MISC', 'value': 'Botuline-tox...         False
# 105                                                 []          True
# 133                                                 []          True
# 55                                                  []          True
# 15                                                  []          True
# 135                                                 []          True
# 6    [{'entityType': 'MISC', 'value': 'Flash Glucos...          True
# 138                                                 []          True
# 139                                                 []          True
# 36                                                  []          True
# 57                                                  []          True
# 120                                                 []          True
# 112                                                 []          True
# 119                                                 []          True
# 111  [{'entityType': 'MISC', 'value': 'Bulgaarse'},...          True
# 122                                                 []          True
# 17                                                  []          True
# 61                                                  []          True
# 144                                                 []          True
# 107                                                 []          True
# 147                                                 []          True
# 19                                                  []          True
# 151                                                 []          True
# 84             [{'entityType': 'ORG', 'value': 'ZGT'}]          True
# 49                                                  []          True
# 73                                                  []          True
# 89                                                  []          True
# 165  [{'entityType': 'MISC', 'value': 'Caelyx'}, {'...          True
# 0                                                   []          True
# 110                                                 []          True
# 63   [{'entityType': 'MISC', 'value': 'Methotrexaat'}]          True
# 41                                                  []          True
# 31                                                  []          True
# 82   [{'entityType': 'MISC', 'value': 'Azathioprine'}]         False
# 156                                                 []          True
# 52                                                  []          True
# 66                                                  []          True
# 28   [{'entityType': 'MISC', 'value': 'Upadacitinib...          True
# 26                                                  []          True
# 123                                                 []          True
# 80                                                  []          True
# 13                                                  []          True
# 125                                                 []          True
# 94                                                  []          True
# 126                                                 []          True
#
#      LLM Score
# 44       100.0
# 127      100.0
# 97       100.0
# 96        85.0
# 131      100.0
# 105       80.0
# 133      100.0
# 55       100.0
# 15       100.0
# 135      100.0
# 6        100.0
# 138      100.0
# 139      100.0
# 36       100.0
# 57       100.0
# 120      100.0
# 112      100.0
# 119      100.0
# 111      100.0
# 122       90.0
# 17       100.0
# 61       100.0
# 144      100.0
# 107      100.0
# 147      100.0
# 19       100.0
# 151      100.0
# 84       100.0
# 49       100.0
# 73       100.0
# 89       100.0
# 165      100.0
# 0        100.0
# 110      100.0
# 63       100.0
# 41       100.0
# 31        95.0
# 82       100.0
# 156       85.0
# 52        90.0
# 66       100.0
# 28        90.0
# 26        90.0
# 123      100.0
# 80       100.0
# 13       100.0
# 125       90.0
# 94       100.0
# 126      100.0

# %% [markdown]
# # Fact Q&A

# %%
sample = loadData(fname, basepath)

sample['Context Entities'] = sample['Document'].apply(extract_all_entities)

new_questions_df = generateFactQuestions(sample)
new_questions_df.to_csv(f"{basepath}/output_fact_raw_{fname}.csv")
df = vectorFilter(new_questions_df)
df = llmScore(df)
df = filterFactQuestionCorrectness(df)

## take top one for each doc
df['Fact Value'] = df['Fact'].apply(lambda x: x.get('value'))
idx = df.groupby(['Document', 'Fact Value'])['LLM Score'].idxmax()
df = df.loc[idx]
# Out:
# Generating Fact QAs: 100%|██████████| 50/50 [00:00<00:00, 15307.68it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 7
#       5 new_questions_df = generateFactQuestions(sample)
#       6 new_questions_df.to_csv(f"{basepath}/output_fact_raw_{fname}.csv")
# ----> 7 df = vectorFilter(new_questions_df)
#       8 df = llmScore(df)
#       9 df = filterFactQuestionCorrectness(df)
#
# Cell In[8], line 5, in vectorFilter(df)
#       4 def vectorFilter(df):
# ----> 5     df["Embedding"] = precompute_embeddings(df, 'Question')
#       6     df = filter_dataframe(df, threshold=0.9)
#       7     return df
#
# File ~/AP_NLP/Automated-QA-Generation/qa-gen/vector_filter.py:13, in precompute_embeddings(df, text_column)
#      12 def precompute_embeddings(df, text_column):
# ---> 13     embeddings = df[text_column].apply(embedder.embed_query)
#      14     return embeddings
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File /usr/local/lib/python3.8/dist-packages/pandas/core/indexes/range.py:349, in RangeIndex.get_loc(self, key)
#     347         raise KeyError(key) from err
#     348 if isinstance(key, Hashable):
# --> 349     raise KeyError(key)
#     350 self._check_indexing_error(key)
#     351 raise KeyError(key)
#
# KeyError: 'Question'

# %%
df.to_csv(f"{basepath}/output_full_fact_{fname}.csv")
df.to_csv(f"{basepath}/output_fact_{fname}.csv", columns = ['topic_id', 'filename', 'header', 'section_text', 'Fact', 'Question', 'Answer'])
