# %%
import nltk
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
fname = "test_fold_one"
basepath = "./-paraphrase-multilingual-MiniLM-L12-v2_3015"

# %% [markdown]
# ## Load data

# %%
import pandas as pd

def loadData(fname, basepath):
    sample = pd.read_csv(f"{basepath}/{fname}.csv")
    sample['Document'] = sample.apply(lambda row: ': '.join(row.astype(str)), axis=1)
    return sample

# %% [markdown]
# ## Question Generation

# %%
from qa_generation import QAGenerator
from prompt_factory import PromptFactory
from tqdm.notebook import tqdm

template = '''
        Gedraag je als een {role} die online informatie zoekt.
        Patiënten stellen meestal vragen als:
{{
    "qa_list": [
        {{
            "question": "Hoe kan ik een verstopte voedingssonde doorspoelen?",
            "answer": "Om een verstopte voedingssonde door te spoelen, kunt u de volgende stappen proberen: 1. Sluit de spuit rechtstreeks aan op de sonde (niet op het voedingssysteem). Als er een verstopping is in het voedingssysteem, kunt u dit vervangen. 2. Neem een spuit van 10 cc en spuit met lichte druk lauwwarm water door de voedingssonde. Herhaal dit zo nodig nog een keer. 3. Als het oplossen van de verstopping niet lukt, laat dan lauwwarm water 30 minuten inwerken en herhaal de bovenstaande procedure nogmaals. 4. Als u de verstopping kunt zien, kunt u proberen om de voedingssonde op die plek zachtjes te kneden. Als de verstopping dan loskomt, kunt u het doorspuiten met lauwwarm water. Belangrijk: Gebruik nooit een voerdraad of koolzuurhoudend bronwater of frisdranken, omdat dit kan leiden tot perforatie. Daarnaast wordt het afraden om natriumbicarbonaat te gebruiken als medicatie de oorzaak is van de verstopping, omdat dit de verstopping groter kan maken."
        }}
    ]
}}


        in het json formaat: 
        {format}

Document Informatie:
        {document}

        Belangrijke Opmerking: Bij het genereren van vragen, gebruik specifieke termen en benamingen uit het document in plaats van algemene termen zoals 'dit onderzoek' of 'die procedure'. Verwijs direct naar de procedure of het document met de exacte naam om nauwkeurigheid en duidelijkheid in de vragen te waarborgen. Vermijd algemeenheden en zorg ervoor dat elke vraag direct gerelateerd is aan de verstrekte documentinformatie.


        Stel {n} vragen die beantwoord kunnen worden op basis van deze paragraaf in het formaat:
        {format}

        Zorg ervoor dat elke vraag en antwoord paar in een geldig JSON-formaat is. Dit betekent dat vragen en antwoorden tussen dubbele aanhalingstekens moeten staan, en de algemene structuur moet overeenkomen met het vereiste JSON-schema.
        '''

roles = [
    'Patiënt',
    'Nieuwe Ouder',
    'Oudere Patiënt',
    'Persoon die een Tweede Mening Zoekt',
    'Reiziger die Medisch Advies Na Reizen Zoekt',
    'Zorgverlener die Informatie Zoekt']

prompt_factory = PromptFactory(prompt=template,roles=roles)

num_questions_per_doc = 5

QAGenerator = QAGenerator()
# Generate the data
import pandas as pd
from tqdm import tqdm


def generateQuestions(df):
    data = []
    for index, row in tqdm(df.iterrows(), total=df.shape[0],desc="Generating QAs"):
        doc = row["Document"]
        # Do something with col1 and col2
        try:
            for i in range(2):
                qa_list = QAGenerator.generate_qas(prompt_factory.generate_prompt(doc, num_questions_per_doc))
                for qa in qa_list:
                    new_row = row.to_dict()
                    new_row['Question'] = qa.question
                    new_row['Answer'] = qa.answer
                    data.append(new_row)

        except Exception as e:
                print(f"Failed to generate QA for doc: {doc[:100]}. Error: {e}")
                continue
    if(len(data) == 0):
       return pd.DataFrame()
    result = pd.DataFrame(data)
    result = result.dropna(subset=['Document', 'Question', 'Answer'])
    result = result[(result['Document'] != '') & (result['Question'] != '') & (result['Answer'] != '')]
    return result

# %%
from fact_qa import FactQAGenerator
from prompt_factory import PromptFactory
import langchain

template = '''
Gedraag je als iemand die online informatie zoekt en stelt vragen gebaseerd op specifieke feiten zoals locatie, telefoonnummer, naam, enzovoort.

Patiënten of gebruikers kunnen bijvoorbeeld vragen stellen als:
{{
    "qa_list": [
        {{
            "question": "Wat is het telefoonnummer van de kliniek voor noodgevallen?",
            "answer": "Het telefoonnummer van de kliniek voor noodgevallen is 012-345-6789."
        }},
        {{
            "question": "Waar is de hoofdingang van het ziekenhuis gelegen?",
            "answer": "De hoofdingang van het ziekenhuis is gelegen aan de Eerste Gezondheidsstraat 123 in Amsterdam."
        }}
        // meer vragen en antwoorden gebaseerd op specifieke feiten
    ]
}}

in het json formaat:
{format}

Document Informatie:
{document}

Belangrijke Opmerking: Bij het genereren van vragen, gebruik specifieke termen en benamingen uit het document in plaats van algemene termen. Verwijs direct naar de specifieke feit (zoals locatie, telefoonnummer, naam) om nauwkeurigheid en duidelijkheid in de vragen te waarborgen. Vermijd algemeenheden.

Maak vragen die beantwoord kunnen worden met de volgende informatie: {fact}

Stel {n} vragen die beantwoord kunnen worden op basis van deze paragraaf in het formaat:
{format}

Zorg ervoor dat elke vraag en antwoord paar in een geldig JSON-formaat is. Dit betekent dat vragen en antwoorden tussen dubbele aanhalingstekens moeten staan, en de algemene structuur moet overeenkomen met het vereiste JSON-schema.
        '''

base_prompt = langchain.PromptTemplate(
            template=template,
            input_variables=['fact', 'n', 'document', 'format']
        )

num_questions_per_doc = 5

FactQAGenerator = FactQAGenerator()

def generateFactQuestions(df):
    data = []
    # Generate the data
    for index, row in tqdm(df.iterrows(), total=df.shape[0],desc="Generating Fact QAs"):
        doc = row['Document']
        # Assuming phone numbers are separated by commas
        facts = row['Context Entities']
        try:
            for i in range(2):
                for entity in extract_desired_entities(facts)[:5]:
                    fact = entity["value"]
                    prompt = base_prompt.partial(
                        n=num_questions_per_doc,
                        document=doc)
                    try:
                        qa_list = FactQAGenerator.generate_question_for_fact(prompt, fact)
                        for qa in qa_list:
                            new_row = row.to_dict()
                            new_row['Question'] = qa.question
                            new_row['Answer'] = qa.answer
                            new_row['Fact'] = entity
                            print(entity)
                            data.append(new_row)
                    except:
                        pass
        except Exception as e:
                print(f"Failed to generate QA for document: {doc[:20]}. Error: {e:20}")

    if(len(data) == 0):
        return pd.DataFrame()

    result = pd.DataFrame(data)
    result = result.dropna(subset=['Document', 'Question', 'Answer'])
    result = result[(result['Document'] != '') & (result['Question'] != '') & (result['Answer'] != '')]
    return result

# %%
def update_df_with_lambda(df, column_name, lambda_function):
     # Check if the column does not exist in the DataFrame, if not, initialize it with NA
    if column_name not in df.columns:
        df[column_name] = pd.NA
    
    # Apply the lambda function only to rows where the column value is NA
    df[column_name] = df.apply(lambda row: lambda_function(row) if pd.isna(row[column_name]) else row[column_name], axis=1)
    return df

# %% [raw]
# ## BLEU / ROUGE filters

# %%
from answer_context_filter import calculate_bleu_score, calculate_rouge_score

def calculate_scores(df):
    # Calculate BLEU and ROUGE scores
    #df['Question-Context BLEU'] = df.apply(lambda row: calculate_bleu_score(row['Document'], row['Question']), axis=1)
    #df['Answer-Context BLEU'] = df.apply(lambda row: calculate_bleu_score(row['Document'], row['Answer']), axis=1)

    #df['Question-Context ROUGE'] = df.apply(lambda row: calculate_rouge_score(row['Document'], row['Question']), axis=1)
    #df['Answer-Context ROUGE'] = df.apply(lambda row: calculate_rouge_score(row['Document'], row['Answer']), axis=1)
    #df['Question-Context ROUGE-L F1'] = df['Question-Context ROUGE'].apply(lambda x: x[0]['rouge-l']['f'] if x else None)
    #df['Answer-Context ROUGE-L F1'] = df['Answer-Context ROUGE'].apply(lambda x: x[0]['rouge-l']['f'] if x else None)

    df = update_df_with_lambda(
        df, 'Question-Context ROUGE',
        lambda row: calculate_rouge_score(row['Document'], row['Question']) if pd.isna(row.get('Question-Context ROUGE')) else row['Question-Context ROUGE']
    )

    # Update 'Answer-Context ROUGE' only if it is NA
    df = update_df_with_lambda(
        df, 'Answer-Context ROUGE',
        lambda row: calculate_rouge_score(row['Document'], row['Answer']) if pd.isna(row.get('Answer-Context ROUGE')) else row['Answer-Context ROUGE']
    )

    # Update 'Question-Context ROUGE-L F1' based on the 'Question-Context ROUGE' column, only if it is NA
    df = update_df_with_lambda(
        df, 'Question-Context ROUGE-L F1',
        lambda row: row['Question-Context ROUGE'][0]['rouge-l']['f'] if pd.isna(row.get('Question-Context ROUGE-L F1')) and row['Question-Context ROUGE'] else None
    )

    # Update 'Answer-Context ROUGE-L F1' based on the 'Answer-Context ROUGE' column, only if it is NA
    df = update_df_with_lambda(
        df, 'Answer-Context ROUGE-L F1',
        lambda row: row['Answer-Context ROUGE'][0]['rouge-l']['f'] if pd.isna(row.get('Answer-Context ROUGE-L F1')) and row['Answer-Context ROUGE'] else None
    )

    return df


def rougeFilter(df):
    df = calculate_scores(df)
    df = df[df['Answer-Context ROUGE-L F1'] > 0.1]
    return df

# %% [markdown]
# ## Vector filter

# %%
from vector_filter import precompute_embeddings
from vector_filter import filter_dataframe

def vectorFilter(df):
    df["Embedding"] = precompute_embeddings(df, 'Question')
    df = filter_dataframe(df, threshold=0.9)
    return df

# %% [markdown]
# ## Entity Filter

# %%
def contains_all_elements(list1, list2):
    """
    Check if list1 contains all elements of list2.
    Each element is a dictionary with 'entityType' and 'value' keys.
    """
    # Convert each dictionary in the lists to a tuple (entityType, value) for easy comparison
    #set1 = {tuple(d.items()) for d in list1}
    #set2 = {tuple(d.items()) for d in list2}
    set1 = {d['value'] for d in list1 if 'value' in d}
    set2 = {d['value'] for d in list2 if 'value' in d}

    # Check if every element in set2 is also in set1
    return set2.issubset(set1)

def check_entity_match(row):
    return contains_all_elements(row['Context Entities'], row['Answer Entities'])

# Apply the function to each row to create the new column

# %%
from extract import extract_all_entities

def extractEntities(df):
    df['Context Entities'] = df['Document'].apply(extract_all_entities)
    df['Question Entities'] = df['Question'].apply(extract_all_entities)
    df['Answer Entities'] = df['Answer'].apply(extract_all_entities)
    df['Entity Match'] = df.apply(check_entity_match, axis=1)
    """  
    df = update_df_with_lambda(df, 'Context Entities', 
                               lambda row: extract_all_entities(row['Document']) 
                                if row.get('Context Entities') is None else row['Context Entities'])

    # Update or create 'Question Entities' column by applying entity extraction function if the value is NA
    df = update_df_with_lambda(df, 'Question Entities', 
                               lambda row: extract_all_entities(row['Question']) 
                               if row.get('Question Entities')is None else row['Question Entities'])

    # Update or create 'Answer Entities' column by applying entity extraction function if the value is NA
    df = update_df_with_lambda(df, 'Answer Entities', 
                               lambda row: extract_all_entities(row['Answer']) 
                               if row.get('Answer Entities') is None else row['Answer Entities'])

    # Update or create 'Entity Match' column by applying the check entity match function if the value is NA
    df = update_df_with_lambda(df, 'Entity Match', 
                               lambda row: check_entity_match(row) 
                               if row.get('Entity Match') is None else row['Entity Match'])
    """
    return df
# Out:
# /home/jovyan/.local/lib/python3.8/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11060). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# 2024-01-18 14:20:18.609526: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-18 14:20:18.738034: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-18 14:20:19.453830: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-18 14:20:19.453903: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/lib:/usr/local/nvidia/lib:/usr/local/nvidia/lib64
# 2024-01-18 14:20:19.453908: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2024-01-18 14:20:35,268 SequenceTagger predicts: Dictionary with 20 tags: <unk>, O, S-ORG, S-MISC, B-PER, E-PER, S-PER, S-LOC, B-MISC, E-MISC, B-ORG, E-ORG, I-ORG, I-PER, B-LOC, I-LOC, E-LOC, I-MISC, <START>, <STOP>

# %%
def contains_desired_entity(entities_list):
    desired_types = {'Phone', 'Email'}
    return any(entity['entityType'] in desired_types for entity in entities_list)


def filterFactQuestions(df):
    df = extractEntities(df)
    return df[~((df['Question'].str.split().str.len() < 30) & df['Answer Entities'].apply(contains_desired_entity))]

def extract_desired_entities(entities_list):
    # Define the desired entity types
    desired_types = {'Phone', 'Email'}
    
    # Extract entities that match the desired types
    matching_entities = [entity for entity in entities_list if entity['entityType'] in desired_types]
    
    return matching_entities

# %%
def filterFactQuestionCorrectness(df):
    df['Answer Entities'] = df['Answer'].apply(extract_all_entities)
    # Apply a filter condition to each row
    #filtered_df = df[df.apply(lambda row: row["Fact"] in row["Answer Entities"], axis=1)]
    filtered_df = df[df.apply(lambda row: any( row["Fact"]['value'] == entity['value'] for entity in row["Answer Entities"]) if isinstance(row["Answer Entities"], list) else False, axis=1)]
    return filtered_df

# %% [markdown]
# #### LLM Scoring

# %%
from llm_filter import estimate_relevance

def llmScore(df):
    return update_df_with_lambda(df, 'LLM Score', lambda row: estimate_relevance(row['Question'], row['Document']))

# %% [markdown]
# # Run

# %%
import os

sample = loadData(fname, basepath)

df = pd.DataFrame(columns = sample.columns)



for i in tqdm(range(5), desc="Processing"):
    raw_file_path = f"{basepath}/output_raw_{i}_{fname}.csv"

    if os.path.exists(raw_file_path):
        # Load the file into a DataFrame if it exists
        print(f"Skipping generation: {i}")
        new_questions_df = pd.read_csv(raw_file_path)
    else:
        df_gen = sample[~sample['Document'].isin(df['Document'])]
        new_questions_df = generateQuestions(df_gen)
        if df_gen.empty:
            break
    new_questions_df.to_csv(raw_file_path)
    df = pd.concat([df, new_questions_df], ignore_index=True, sort=False)
    df = rougeFilter(df)
    df = vectorFilter(df)
    df = filterFactQuestions(df)
    df = llmScore(df)


## take top one for each doc
idx = df.groupby('Document')['LLM Score'].idxmax()
df = df.loc[idx]

df.to_csv(f"{basepath}/output_full_{fname}.csv")
df.to_csv(f"{basepath}/output_{fname}.csv", columns = ['topic_id', 'filename', 'header', 'section_text', 'Question', 'Answer'])
# Out:
# Processing:   0%|          | 0/5 [00:00<?, ?it/s]
# Generating QAs:   0%|          | 0/50 [00:00<?, ?it/s]
# Generating QAs:   2%|▏         | 1/50 [00:17<14:13, 17.41s/it]
# Generating QAs:   4%|▍         | 2/50 [00:27<10:35, 13.23s/it]
# Generating QAs:   6%|▌         | 3/50 [00:40<10:06, 12.90s/it]
# Failed to generate QA for doc: 55: Gemalen voeding bij slikklachten: Vragen: Heeft u na het lezen van deze folder nog vragen? Neem . Error: 'list' object has no attribute 'qa_list'
# Generating QAs:   8%|▊         | 4/50 [00:49<08:52, 11.58s/it]
# Generating QAs:  10%|█         | 5/50 [00:58<07:50, 10.46s/it]
# Generating QAs:  12%|█▏        | 6/50 [01:10<08:03, 10.99s/it]
# Generating QAs:  14%|█▍        | 7/50 [01:21<07:51, 10.96s/it]
# Generating QAs:  16%|█▌        | 8/50 [01:37<08:50, 12.63s/it]
# Generating QAs:  18%|█▊        | 9/50 [01:49<08:30, 12.46s/it]
# Generating QAs:  20%|██        | 10/50 [02:04<08:45, 13.13s/it]
# Generating QAs:  22%|██▏       | 11/50 [02:25<10:14, 15.76s/it]
# Generating QAs:  24%|██▍       | 12/50 [02:43<10:24, 16.44s/it]
# Generating QAs:  26%|██▌       | 13/50 [02:58<09:51, 15.98s/it]
# Generating QAs:  28%|██▊       | 14/50 [03:28<12:00, 20.00s/it]
# Generating QAs:  30%|███       | 15/50 [03:37<09:52, 16.92s/it]
# Generating QAs:  32%|███▏      | 16/50 [03:57<09:58, 17.61s/it]
# Generating QAs:  34%|███▍      | 17/50 [04:29<12:07, 22.06s/it]
# Generating QAs:  36%|███▌      | 18/50 [04:41<10:12, 19.14s/it]
# Generating QAs:  38%|███▊      | 19/50 [04:53<08:42, 16.87s/it]
# Generating QAs:  40%|████      | 20/50 [05:04<07:34, 15.15s/it]
# Generating QAs:  42%|████▏     | 21/50 [05:16<06:53, 14.24s/it]
# Generating QAs:  44%|████▍     | 22/50 [05:37<07:34, 16.22s/it]
# Generating QAs:  46%|████▌     | 23/50 [05:48<06:34, 14.60s/it]
# Generating QAs:  48%|████▊     | 24/50 [06:09<07:12, 16.62s/it]
# Generating QAs:  50%|█████     | 25/50 [06:31<07:33, 18.15s/it]
# Generating QAs:  52%|█████▏    | 26/50 [06:44<06:40, 16.69s/it]
# Generating QAs:  54%|█████▍    | 27/50 [07:04<06:47, 17.72s/it]
# Generating QAs:  56%|█████▌    | 28/50 [07:20<06:17, 17.17s/it]
# Generating QAs:  58%|█████▊    | 29/50 [07:39<06:14, 17.82s/it]
# Generating QAs:  60%|██████    | 30/50 [07:51<05:17, 15.88s/it]
# Generating QAs:  62%|██████▏   | 31/50 [08:06<04:58, 15.72s/it]
# Generating QAs:  64%|██████▍   | 32/50 [08:22<04:46, 15.89s/it]
# Generating QAs:  66%|██████▌   | 33/50 [08:36<04:18, 15.22s/it]
# Generating QAs:  68%|██████▊   | 34/50 [08:57<04:31, 17.00s/it]
# Generating QAs:  70%|███████   | 35/50 [09:09<03:53, 15.55s/it]
# Generating QAs:  72%|███████▏  | 36/50 [09:30<04:00, 17.20s/it]
# Generating QAs:  74%|███████▍  | 37/50 [09:39<03:10, 14.62s/it]
# Generating QAs:  76%|███████▌  | 38/50 [09:50<02:41, 13.44s/it]
# Generating QAs:  78%|███████▊  | 39/50 [10:04<02:30, 13.68s/it]
# Generating QAs:  80%|████████  | 40/50 [10:24<02:37, 15.70s/it]
# Failed to generate QA for doc: 3: Geestelijke verzorging, ondersteuning en begeleiding van nierpatiënten: Kennismaken: Indien u heb. Error: 'list' object has no attribute 'qa_list'
# Generating QAs:  82%|████████▏ | 41/50 [10:44<02:31, 16.79s/it]
# Generating QAs:  84%|████████▍ | 42/50 [10:57<02:06, 15.76s/it]
# Generating QAs:  86%|████████▌ | 43/50 [11:08<01:39, 14.21s/it]
# Generating QAs:  88%|████████▊ | 44/50 [11:27<01:34, 15.67s/it]
# Generating QAs:  90%|█████████ | 45/50 [11:40<01:13, 14.80s/it]
# Generating QAs:  92%|█████████▏| 46/50 [12:03<01:10, 17.51s/it]
# Generating QAs:  94%|█████████▍| 47/50 [12:23<00:54, 18.24s/it]
# Generating QAs:  96%|█████████▌| 48/50 [12:39<00:35, 17.52s/it]
# Generating QAs:  98%|█████████▊| 49/50 [12:53<00:16, 16.33s/it]
# Generating QAs: 100%|██████████| 50/50 [13:11<00:00, 15.83s/it]
# Processing:  20%|██        | 1/5 [17:29<1:09:58, 1049.74s/it]
# Generating QAs:   0%|          | 0/6 [00:00<?, ?it/s]
# Generating QAs:  17%|█▋        | 1/6 [00:14<01:12, 14.47s/it]
# Generating QAs:  33%|███▎      | 2/6 [00:34<01:10, 17.57s/it]
# Generating QAs:  50%|█████     | 3/6 [00:50<00:51, 17.09s/it]
# Generating QAs:  67%|██████▋   | 4/6 [01:00<00:28, 14.18s/it]
# Generating QAs:  83%|████████▎ | 5/6 [01:10<00:12, 12.66s/it]
# Generating QAs: 100%|██████████| 6/6 [01:24<00:00, 14.09s/it]
# Processing:  40%|████      | 2/5 [20:43<27:19, 546.34s/it]
# Skipping generation: 2
# Processing:  60%|██████    | 3/5 [22:08<11:11, 335.64s/it]
# Skipping generation: 3
# Processing:  80%|████████  | 4/5 [23:29<03:55, 235.05s/it]
# Skipping generation: 4
# Processing: 100%|██████████| 5/5 [25:01<00:00, 300.29s/it]

# %% [markdown]
# ## Export Q&A Pairs

# %%
df.to_csv(f"{basepath}/output_full_{fname}.csv")
df.to_csv(f"{basepath}/output_{fname}.csv", columns = ['topic_id', 'filename', 'header', 'section_text', 'Question', 'Answer'])

# %%
df
# Out:
#     topic_id                                           filename  \
# 40         0                       Afdeling 5 west (ZGT Almelo)
# 97         0                          Anesthesie kinderen (POS)
# 158        0  CVA revalidatie, revalidatie na een herseninfa...
# 154        0                          Cardiologische nazorgpoli
# 95         0              Follow-up Borstkliniek Oost-Nederland
# 93         0                 Gezonde moeder of rooming-in ouder
# 88         0                                      Madentherapie
# 91         0          Schisis, sluiting van het harde gehemelte
# 24        12                    Borstvoeding na ontslag uit ZGT
# 136       12                    Borstvoeding na ontslag uit ZGT
# 16        21                                      Beenamputatie
# 138       21            Twijgbreuk (VFC, Virtual Fracture Care)
# 6         26                                     Bryant-tractie
# 142       26  Ontslagbericht, instructies voor thuis heelkun...
# 86        27                     Polysomnografie ambulant (PSG)
# 73        28                                     Echocardiogram
# 146       28                         Ejectiefractiemeting (PYP)
# 38         2                          Anesthesie kinderen (POS)
# 102        2                         Hongerprovocatie, klinisch
# 103        2          Schisis, sluiting van het harde gehemelte
# 99         2          Schisis, sluiting van het harde gehemelte
# 20        31  Afspraak op de multidisciplinaire polikliniek ...
# 45        32                        Diagnostische hysteroscopie
# 54        38                         Ejectiefractiemeting (PYP)
# 5          3  Afspraak op de multidisciplinaire polikliniek ...
# 109        3  Afspraak op de multidisciplinaire polikliniek ...
# 159        3  Geestelijke verzorging, ondersteuning en begel...
# 112        3                             Knobbeltje in de borst
# 120        3                Post intensive care syndroom (PICS)
# 116        3  Programma Terug naar Evenwicht, patiënteninfor...
# 63        40                              Antegrade pyelografie
# 32        46                                             Opname
# 28        47  Reglement Klachtenonderzoekscommissie Ziekenhu...
# 48        48                                     Bryant-tractie
# 46        49      Poliklinische revalidatiebehandeling kinderen
# 10         4                              Antegrade pyelografie
# 122        4                                    Sonde inbrengen
# 58        52                      D8 Cognitieve gedragstherapie
# 83        53                      Laparoscopische ingreep blaas
# 67        54                 Gezonde moeder of rooming-in ouder
# 150       55                   Gemalen voeding bij slikklachten
# 152       58                          Anesthesie kinderen (POS)
# 71        59  Het verlies van uw kind, tijdens de zwangersch...
# 84        61                        Diagnostische hysteroscopie
# 1          7  Het verlies van uw kind, tijdens de zwangersch...
# 135        7                                           Miskraam
# 128        7                                           Miskraam
# 80         8                                             Afasie
#
#                                                 header  \
# 40                              Belangrijke informatie
# 97                                   Vragen en contact
# 158          Nuttige adressen en patiëntenverenigingen
# 154                                    Heeft u vragen?
# 95                                      Afspraak maken
# 93               Afdeling moeder en kind (verloskunde)
# 88                                              Vragen
# 91                               Victor Veau stichting
# 24                             Borstvoeding na ontslag
# 136                                       Hulpmiddelen
# 16                         Check uw dossier op MijnZGT
# 138                          Virtual Fracture Care App
# 6                                               Vragen
# 142                                           Tot slot
# 86                                          Resultaten
# 73                           Verloop van het onderzoek
# 146                         Ejectiefractiemeting (HSA)
# 38                                        Nuchter zijn
# 102                         Klinische hongerprovocatie
# 103                                        De operatie
# 99                                     Eten en drinken
# 20            Wekelijkse multidisciplinaire bespreking
# 45                         Hoe verloopt het onderzoek?
# 54                 Hoe gaat het onderzoek in zijn werk
# 5     Uw afspraak op de multidisciplinaire polikliniek
# 109                    Uw tips en adviezen zijn welkom
# 159                                        Kennismaken
# 112                                        Behandeling
# 120      Kunnen naasten ook PICS klachten ontwikkelen?
# 116  6.2 Module Medische Psychologie; Leren leven m...
# 63                                      Waarschuwingen
# 32                                De dag van de opname
# 28               Reglement Klachtenonderzoekscommissie
# 48                                      Bryant-tractie
# 46                                      Vervoerskosten
# 10                Foto’s van de nieren en urineleiders
# 122                                             Nazorg
# 58                                       Geheimhouding
# 83                                              Vragen
# 67                                           Inleiding
# 150                                             Vragen
# 152                        Check uw dossier op MijnZGT
# 71                                   Weer aan het werk
# 84                                     Meer informatie
# 1      Zwangerschapsafbreking na prenatale diagnostiek
# 135            Andere oorzaken van bloedverlies en EUG
# 128                        Welk onderzoek is mogelijk?
# 80                           Afasie en hoe nu verder……
#
#                                           section_text  \
# 40   Bij problemen en vragen kunt u in eerste insta...
# 97   Neem dan gerust contact op met ZGT polikliniek...
# 158  De Nederlandse CVA-vereniging “Samen verder” P...
# 154  Voor vragen zijn wij op werkdagen van 8.00 - 1...
# 95   Wanneer het tijd is voor uw controlebezoek kri...
# 93   Ziekenhuislocatie Almelo, telefoonnummer 088 7...
# 88   Heeft u naar aanleiding van deze folder vragen...
# 91   Telefoonnummer 06 30 37 73 65 E-mail: secretar...
# 24   Deze folder geeft u informatie over begeleidin...
# 136  Na ontslag zijn er verschillende mogelijkheden...
# 16   MijnZGT is het patiënten portaal van ZGT. U ku...
# 138  Deze app is bedoeld voor patiënten die in ZGT ...
# 6    Mocht u nog vragen hebben, dan kunt u deze ste...
# 142  Heeft u na het lezen van deze tekst nog vragen...
# 86   Na ongeveer 2 weken bespreekt de slaapspeciali...
# 73   Voor dit onderzoek vragen wij u het bovenlicha...
# 146  Bij een ejectiefractiemeting worden foto’s van...
# 38   In verband met de veiligheid moet uw kind nuch...
# 102  Binnenkort wordt uw kind opgenomen voor een kl...
# 103  Wanneer uw kind aan de beurt is voor de operat...
# 99   Meestal mag uw kind enkele uren na de operatie...
# 20   Nadat bij u het onderzoekstraject is afgerond ...
# 45   Het onderzoek vindt zonder verdoving plaats. U...
# 54   Bij aankomst op de afdeling nucleaire geneesku...
# 5    Voor uw behandeling kunt u te maken krijgen me...
# 109  Wij streven ernaar om de zorg voor u goed te l...
# 159  Indien u hebt aangegeven behoefte te hebben aa...
# 112  Afhankelijk van de aard van het knobbeltje en ...
# 120  Een opname op de IC is voor alle betrokken en ...
# 116  De meeste mensen ervaren na hun ziekte in meer...
# 63   Het is ongewenst, dat dit onderzoek wordt uitg...
# 32   U meldt zich op het afgesproken tijdstip bij d...
# 28   Ziekenhuizen Oost-Nederland Artikel 1 Algemeen...
# 48   Uw kind is opgenomen vanwege een bovenbeenbreu...
# 46   Onder bepaalde voorwaarden en afhankelijk van ...
# 10   (antegrade pyelografie) Uw behandelend medisch...
# 122  Uw medisch specialist zal met u het verzorgen ...
# 58   Alle medewerkers van de afdelingen psychiatrie...
# 83   Heeft u naar aanleiding van deze folder vragen...
# 67   Dat betekent dat u bij uw baby kunt verblijven...
# 150  Heeft u na het lezen van deze folder nog vrage...
# 152  MijnZGT is het patiëntenportaal van ZGT. U kun...
# 71   Denk goed na of en wanneer u weer aan het werk...
# 84   Nederlandse Vereniging voor Obstetrie en Gynae...
# 1    Prenatale diagnostiek is onderzoek tijdens de ...
# 135  Bloedverlies in het begin van de zwangerschap ...
# 128  Bij bloedverlies vroeg in de zwangerschap kan ...
# 80   Deze folder geeft u informatie over wat afasie...
#
#                                               Document  \
# 40   0: Afdeling 5 west (ZGT Almelo): Belangrijke i...
# 97   0: Anesthesie kinderen (POS): Vragen en contac...
# 158  0: CVA revalidatie, revalidatie na een herseni...
# 154  0: Cardiologische nazorgpoli: Heeft u vragen?:...
# 95   0: Follow-up Borstkliniek Oost-Nederland: Afsp...
# 93   0: Gezonde moeder of rooming-in ouder: Afdelin...
# 88   0: Madentherapie: Vragen: Heeft u naar aanleid...
# 91   0: Schisis, sluiting van het harde gehemelte: ...
# 24   12: Borstvoeding na ontslag uit ZGT: Borstvoed...
# 136  12: Borstvoeding na ontslag uit ZGT: Hulpmidde...
# 16   21: Beenamputatie: Check uw dossier op MijnZGT...
# 138  21: Twijgbreuk (VFC, Virtual Fracture Care): V...
# 6    26: Bryant-tractie: Vragen: Mocht u nog vragen...
# 142  26: Ontslagbericht, instructies voor thuis hee...
# 86   27: Polysomnografie ambulant (PSG): Resultaten...
# 73   28: Echocardiogram: Verloop van het onderzoek:...
# 146  28: Ejectiefractiemeting (PYP): Ejectiefractie...
# 38   2: Anesthesie kinderen (POS): Nuchter zijn: In...
# 102  2: Hongerprovocatie, klinisch: Klinische honge...
# 103  2: Schisis, sluiting van het harde gehemelte: ...
# 99   2: Schisis, sluiting van het harde gehemelte: ...
# 20   31: Afspraak op de multidisciplinaire poliklin...
# 45   32: Diagnostische hysteroscopie: Hoe verloopt ...
# 54   38: Ejectiefractiemeting (PYP): Hoe gaat het o...
# 5    3: Afspraak op de multidisciplinaire poliklini...
# 109  3: Afspraak op de multidisciplinaire poliklini...
# 159  3: Geestelijke verzorging, ondersteuning en be...
# 112  3: Knobbeltje in de borst: Behandeling: Afhank...
# 120  3: Post intensive care syndroom (PICS): Kunnen...
# 116  3: Programma Terug naar Evenwicht, patiëntenin...
# 63   40: Antegrade pyelografie: Waarschuwingen: Het...
# 32   46: Opname: De dag van de opname: U meldt zich...
# 28   47: Reglement Klachtenonderzoekscommissie Ziek...
# 48   48: Bryant-tractie: Bryant-tractie: Uw kind is...
# 46   49: Poliklinische revalidatiebehandeling kinde...
# 10   4: Antegrade pyelografie: Foto’s van de nieren...
# 122  4: Sonde inbrengen: Nazorg: Uw medisch special...
# 58   52: D8 Cognitieve gedragstherapie: Geheimhoudi...
# 83   53: Laparoscopische ingreep blaas: Vragen: Hee...
# 67   54: Gezonde moeder of rooming-in ouder: Inleid...
# 150  55: Gemalen voeding bij slikklachten: Vragen: ...
# 152  58: Anesthesie kinderen (POS): Check uw dossie...
# 71   59: Het verlies van uw kind, tijdens de zwange...
# 84   61: Diagnostische hysteroscopie: Meer informat...
# 1    7: Het verlies van uw kind, tijdens de zwanger...
# 135  7: Miskraam: Andere oorzaken van bloedverlies ...
# 128  7: Miskraam: Welk onderzoek is mogelijk?: Bij ...
# 80   8: Afasie: Afasie en hoe nu verder……: Deze fol...
#
#                                               Question  \
# 40   Wanneer is de beste tijd om de verantwoordelij...
# 97   Op welke dagen en tijden kan ik bellen met ZGT...
# 158  Wat is het bezoekadres van Roessingh, centrum ...
# 154  Wat is het verzoek bij het sturen van een e-mail?
# 95   Wanneer ontvang ik een uitnodiging voor mijn c...
# 93   Welke afdeling is verantwoordelijk voor verlos...
# 88   Wat is het belang van dagelijks contact met de...
# 91         Wat is de sluiting van het harde gehemelte?
# 24   Welke informatie wordt gegeven in de folder Bo...
# 136  Welke mogelijkheden zijn er voor het huren of ...
# 16            Moet ik betalen om MijnZGT te gebruiken?
# 138  Welk letsel wordt in de VFC app aangeduid als ...
# 6    Aan wie kan ik mijn vragen over de Bryant-trac...
# 142  Waar kan ik terecht als ik na het lezen van di...
# 86   Hoe lang duurt het voordat de resultaten van e...
# 73   Wat zijn de drie plakelektroden die tijdens ee...
# 146  Welke informatie kan worden verkregen uit een ...
# 38   Welke dranken mogen baby's van 0-6 maanden heb...
# 102  Wat kunt u verwachten tijdens de opname voor e...
# 103  Wie begeleidt u naar de operatiekamer voor de ...
# 99   Wanneer mag mijn kind na de operatie weer begi...
# 20   Wat gebeurt er na afloop van het onderzoekstra...
# 45       Hoe verloopt een diagnostische hysteroscopie?
# 54   Bij welke afdeling moet ik mij melden voor de ...
# 5    Wat is het doel van een afspraak op de multidi...
# 109  Is het mogelijk om tips en adviezen te geven a...
# 159  Wanneer zal mijn verzoek voor een gesprek met ...
# 112  Wat is het verschil in behandeling afhankelijk...
# 120  Kunnen familieleden geestelijke gezondheidspro...
# 116  Wat is de beste manier om om te gaan met angst...
# 63   Wat moet ik doen als ik zwanger ben tijdens he...
# 32   Wat betekent het dat er gemengd wordt verpleeg...
# 28   Wat is de relatie tussen dit reglement en de K...
# 48         Wat is de reden dat mijn kind is opgenomen?
# 46   Komen patiënten in aanmerking voor vergoeding ...
# 10                       Wat is Antegrade pyelografie?
# 122  Welke vorm van nazorg kan ik verwachten na het...
# 58   Wat is de geheimhoudingsplicht van medewerkers...
# 83   Kan ik contact opnemen met de polikliniek urol...
# 67   Valt de opname als gezonde moeder onder de bas...
# 150  Kan ik na het lezen van deze folder contact op...
# 152  Wat zijn de mogelijkheden van MijnZGT voor oud...
# 71   Kan ik weer aan het werk na het verlies van mi...
# 84                      Wat is de website van de NVOG?
# 1    Wat betekent het voor ouders om de zwangerscha...
# 135               Wat kan de kans op een EUG verhogen?
# 128  Wat kan een inwendig onderzoek met behulp van ...
# 80                                  Wat is een afasie?
#
#                                                 Answer  \
# 40   Het wordt aangeraden om de verantwoordelijke v...
# 97   U kunt bellen met ZGT polikliniek preoperatiev...
# 158  Het bezoekadres van Roessingh, centrum voor re...
# 154  Vermeld in de e-mail s.v.p. uw achternaam en g...
# 95   U ontvangt een uitnodiging van ons wanneer het...
# 93   De afdeling moeder en kind is verantwoordelijk...
# 88   Het dagelijks contact met de polikliniek chiru...
# 91   De sluiting van het harde gehemelte is een ope...
# 24   De folder geeft informatie over begeleiding bi...
# 136  Na ontslag uit ZGT zijn er verschillende mogel...
# 16   Nee, MijnZGT is gratis voor patiënten van ZGT....
# 138  In de VFC app wordt het letsel 'Twijgbreukje p...
# 6    U kunt uw vragen over de Bryant-tractie stelle...
# 142  U kunt uw vragen stellen aan uw behandelend me...
# 86   Na ongeveer 2 weken bespreekt de slaapspeciali...
# 73   De drie plakelektroden die tijdens een Echocar...
# 146  Een ejectiefractiemeting kan de pompfunctie va...
# 38   Baby's van 0 tot 6 maanden mogen tot 4 uur voo...
# 102  Tijdens de opname voor een klinische hongerpro...
# 103  Wanneer uw kind aan de beurt is voor de operat...
# 99   Meestal mag uw kind enkele uren na de operatie...
# 20   Na afloop van het onderzoekstraject worden de ...
# 45   Een diagnostische hysteroscopie vindt zonder v...
# 54   U moet zich aanmelden bij de balie van de afde...
# 5    Het doel van een afspraak op de multidisciplin...
# 109  Ja, het is mogelijk om tips en adviezen te gev...
# 159  Indien u hebt aangegeven behoefte te hebben aa...
# 112  De chirurg zal na het multidisciplinaire overl...
# 120  Ja, familieleden kunnen geestelijke gezondheid...
# 116  Na een ziekte is het normaal om angst te ervar...
# 63   Als u zwanger bent of denkt te zijn, moet u co...
# 32   Gemengd verplegen betekent dat mannen en vrouw...
# 28   Dit reglement is een uitwerking van artikel 8 ...
# 48    Uw kind is opgenomen vanwege een bovenbeenbreuk.
# 46   Patiënten kunnen in aanmerking komen voor verg...
# 10   Antegrade pyelografie is een radiologische pro...
# 122  Uw medisch specialist zal met u het verzorgen ...
# 58   Alle medewerkers hebben een geheimhoudingsplic...
# 83   Ja, als u vragen heeft over deze ingreep of an...
# 67   Ja, de opname als gezonde moeder valt onder de...
# 150  Ja, u kunt gerust contact opnemen met de diëti...
# 152  Op MijnZGT kunt u het medisch dossier van uw k...
# 71   Het is belangrijk om goed na te denken of en w...
# 84                  De website van de NVOG is nvog.nl.
# 1    Voor ouders betekent het afbreken van de zwang...
# 135  Na een eileiderontsteking, een operatie aan de...
# 128  Een inwendig onderzoek kan aantonen of er spra...
# 80   Afasie is een taalstoornis die het gevolg is v...
#
#                                 Question-Context ROUGE  \
# 40   [{'rouge-1': {'r': 0.1016949152542373, 'p': 0....
# 97   [{'rouge-1': {'r': 0.14814814814814814, 'p': 0...
# 158  [{'rouge-1': {'r': 0.025477707006369428, 'p': ...
# 154  [{'rouge-1': {'r': 0.023809523809523808, 'p': ...
# 95   [{'rouge-1': {'r': 0.2, 'p': 0.5, 'f': 0.28571...
# 93   [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, '...
# 88   [{'rouge-1': {'r': 0.14705882352941177, 'p': 0...
# 91   [{'rouge-1': {'r': 0.14814814814814814, 'p': 0...
# 24   [{'rouge-1': {'r': 0.13636363636363635, 'p': 0...
# 136  [{'rouge-1': {'r': 0.52, 'p': 0.86666666666666...
# 16   [{'rouge-1': {'r': 0.023809523809523808, 'p': ...
# 138  [{'rouge-1': {'r': 0.11940298507462686, 'p': 0...
# 6    [{'rouge-1': {'r': 0.06666666666666667, 'p': 0...
# 142  [{'rouge-1': {'r': 0.14285714285714285, 'p': 0...
# 86   [{'rouge-1': {'r': 0.06896551724137931, 'p': 0...
# 73   [{'rouge-1': {'r': 0.11666666666666667, 'p': 0...
# 146  [{'rouge-1': {'r': 0.0851063829787234, 'p': 0....
# 38   [{'rouge-1': {'r': 0.06930693069306931, 'p': 0...
# 102  [{'rouge-1': {'r': 0.2903225806451613, 'p': 0....
# 103  [{'rouge-1': {'r': 0.11842105263157894, 'p': 0...
# 99   [{'rouge-1': {'r': 0.09876543209876543, 'p': 0...
# 20   [{'rouge-1': {'r': 0.0425531914893617, 'p': 0....
# 45   [{'rouge-1': {'r': 0.030303030303030304, 'p': ...
# 54   [{'rouge-1': {'r': 0.0684931506849315, 'p': 0....
# 5    [{'rouge-1': {'r': 0.18604651162790697, 'p': 0...
# 109  [{'rouge-1': {'r': 0.23076923076923078, 'p': 0...
# 159  [{'rouge-1': {'r': 0.17073170731707318, 'p': 0...
# 112  [{'rouge-1': {'r': 0.1346153846153846, 'p': 0....
# 120  [{'rouge-1': {'r': 0.11475409836065574, 'p': 0...
# 116  [{'rouge-1': {'r': 0.06818181818181818, 'p': 0...
# 63   [{'rouge-1': {'r': 0.06896551724137931, 'p': 0...
# 32   [{'rouge-1': {'r': 0.09411764705882353, 'p': 0...
# 28   [{'rouge-1': {'r': 0.25, 'p': 0.58333333333333...
# 48   [{'rouge-1': {'r': 0.06666666666666667, 'p': 0...
# 46   [{'rouge-1': {'r': 0.13157894736842105, 'p': 0...
# 10   [{'rouge-1': {'r': 0.031746031746031744, 'p': ...
# 122  [{'rouge-1': {'r': 0.11538461538461539, 'p': 0...
# 58   [{'rouge-1': {'r': 0.11764705882352941, 'p': 0...
# 83   [{'rouge-1': {'r': 0.22727272727272727, 'p': 0...
# 67   [{'rouge-1': {'r': 0.06451612903225806, 'p': 0...
# 150  [{'rouge-1': {'r': 0.2553191489361702, 'p': 0....
# 152  [{'rouge-1': {'r': 0.08888888888888889, 'p': 0...
# 71   [{'rouge-1': {'r': 0.1590909090909091, 'p': 0....
# 84   [{'rouge-1': {'r': 0.0, 'p': 0.0, 'f': 0.0}, '...
# 1    [{'rouge-1': {'r': 0.2191780821917808, 'p': 0....
# 135  [{'rouge-1': {'r': 0.05263157894736842, 'p': 0...
# 128  [{'rouge-1': {'r': 0.09900990099009901, 'p': 0...
# 80   [{'rouge-1': {'r': 0.047619047619047616, 'p': ...
#
#                                   Answer-Context ROUGE  \
# 40   [{'rouge-1': {'r': 0.3220338983050847, 'p': 0....
# 97   [{'rouge-1': {'r': 0.42592592592592593, 'p': 1...
# 158  [{'rouge-1': {'r': 0.05732484076433121, 'p': 0...
# 154  [{'rouge-1': {'r': 0.2619047619047619, 'p': 1....
# 95   [{'rouge-1': {'r': 0.5, 'p': 0.769230769230769...
# 93   [{'rouge-1': {'r': 0.17647058823529413, 'p': 0...
# 88   [{'rouge-1': {'r': 0.14705882352941177, 'p': 0...
# 91   [{'rouge-1': {'r': 0.14814814814814814, 'p': 0...
# 24   [{'rouge-1': {'r': 0.29545454545454547, 'p': 0...
# 136  [{'rouge-1': {'r': 0.8, 'p': 0.952380952380952...
# 16   [{'rouge-1': {'r': 0.21428571428571427, 'p': 0...
# 138  [{'rouge-1': {'r': 0.1044776119402985, 'p': 0....
# 6    [{'rouge-1': {'r': 0.36666666666666664, 'p': 0...
# 142  [{'rouge-1': {'r': 0.2, 'p': 0.636363636363636...
# 86   [{'rouge-1': {'r': 0.41379310344827586, 'p': 1...
# 73   [{'rouge-1': {'r': 0.21666666666666667, 'p': 0...
# 146  [{'rouge-1': {'r': 0.2127659574468085, 'p': 0....
# 38   [{'rouge-1': {'r': 0.2079207920792079, 'p': 0....
# 102  [{'rouge-1': {'r': 0.2903225806451613, 'p': 0....
# 103  [{'rouge-1': {'r': 0.18421052631578946, 'p': 1...
# 99   [{'rouge-1': {'r': 0.16049382716049382, 'p': 1...
# 20   [{'rouge-1': {'r': 0.3617021276595745, 'p': 0....
# 45   [{'rouge-1': {'r': 0.1717171717171717, 'p': 0....
# 54   [{'rouge-1': {'r': 0.1232876712328767, 'p': 0....
# 5    [{'rouge-1': {'r': 0.2558139534883721, 'p': 0....
# 109  [{'rouge-1': {'r': 0.23076923076923078, 'p': 0...
# 159  [{'rouge-1': {'r': 0.4878048780487805, 'p': 1....
# 112  [{'rouge-1': {'r': 0.36538461538461536, 'p': 0...
# 120  [{'rouge-1': {'r': 0.3114754098360656, 'p': 0....
# 116  [{'rouge-1': {'r': 0.38636363636363635, 'p': 0...
# 63   [{'rouge-1': {'r': 0.3793103448275862, 'p': 0....
# 32   [{'rouge-1': {'r': 0.11764705882352941, 'p': 0...
# 28   [{'rouge-1': {'r': 0.6428571428571429, 'p': 1....
# 48   [{'rouge-1': {'r': 0.23333333333333334, 'p': 1...
# 46   [{'rouge-1': {'r': 0.2631578947368421, 'p': 0....
# 10   [{'rouge-1': {'r': 0.20634920634920634, 'p': 0...
# 122  [{'rouge-1': {'r': 0.46153846153846156, 'p': 1...
# 58   [{'rouge-1': {'r': 0.17647058823529413, 'p': 1...
# 83   [{'rouge-1': {'r': 0.45454545454545453, 'p': 0...
# 67   [{'rouge-1': {'r': 0.17204301075268819, 'p': 0...
# 150  [{'rouge-1': {'r': 0.14893617021276595, 'p': 0...
# 152  [{'rouge-1': {'r': 0.37777777777777777, 'p': 0...
# 71   [{'rouge-1': {'r': 0.6363636363636364, 'p': 0....
# 84   [{'rouge-1': {'r': 0.125, 'p': 0.25, 'f': 0.16...
# 1    [{'rouge-1': {'r': 0.4657534246575342, 'p': 0....
# 135  [{'rouge-1': {'r': 0.14035087719298245, 'p': 1...
# 128  [{'rouge-1': {'r': 0.1485148514851485, 'p': 0....
# 80   [{'rouge-1': {'r': 0.19047619047619047, 'p': 0...
#
#      Question-Context ROUGE-L F1  Answer-Context ROUGE-L F1  \
# 40                      0.054795                   0.325581
# 97                      0.235294                   0.597403
# 158                     0.048193                   0.105882
# 154                     0.039216                   0.415094
# 95                      0.214286                   0.363636
# 93                      0.000000                   0.206897
# 88                      0.222222                   0.192308
# 91                      0.228571                   0.170213
# 24                      0.222222                   0.433333
# 136                     0.450000                   0.826087
# 16                      0.040816                   0.290323
# 138                     0.177215                   0.153846
# 6                       0.100000                   0.454545
# 142                     0.204082                   0.304348
# 86                      0.046512                   0.585366
# 73                      0.191781                   0.337662
# 146                     0.145455                   0.307692
# 38                      0.121739                   0.285714
# 102                     0.380952                   0.266667
# 103                     0.112360                   0.311111
# 99                      0.173913                   0.276596
# 20                      0.036364                   0.515152
# 45                      0.057692                   0.285714
# 54                      0.120482                   0.119048
# 5                       0.259259                   0.295082
# 109                     0.296296                   0.290909
# 159                     0.264151                   0.655738
# 112                     0.222222                   0.320000
# 120                     0.194444                   0.377778
# 116                     0.118812                   0.474074
# 63                      0.047619                   0.416667
# 32                      0.168421                   0.206186
# 28                      0.250000                   0.782609
# 48                      0.105263                   0.378378
# 46                      0.217391                   0.222222
# 10                      0.059701                   0.320988
# 122                     0.157895                   0.631579
# 58                      0.150000                   0.250000
# 83                      0.312500                   0.318182
# 67                      0.118812                   0.280702
# 150                     0.322581                   0.241379
# 152                     0.150943                   0.484848
# 71                      0.181818                   0.642857
# 84                      0.000000                   0.166667
# 1                       0.344086                   0.530973
# 135                     0.098361                   0.246154
# 128                     0.176991                   0.233333
# 80                      0.080000                   0.200000
#
#                                              Embedding  \
# 40   [0.015346979065916389, -0.02335966420286628, 0...
# 97   [0.0015574133475772627, -0.02143312744446034, ...
# 158  [0.02015472410168831, -0.015820374872564914, 0...
# 154  [0.0010312061294578145, -0.034699813326347945,...
# 95   [-0.002944429192951676, -0.03932623592909306, ...
# 93   [0.0262017725345024, -0.02287935922128619, 0.0...
# 88   [0.018920464964401564, -0.0025052338134383878,...
# 91   [0.023590638334913108, -0.019207823289863382, ...
# 24   [-0.017886174867401194, -0.013472535194354896,...
# 136  [0.0011145766535779222, -0.04024312132163732, ...
# 16   [0.006376909037752219, -0.030130338004688433, ...
# 138  [-0.004034518338418321, -0.012241542564414946,...
# 6    [-0.011039378790936872, -0.023040964652882724,...
# 142  [-0.009533150051531674, -0.035813219582183094,...
# 86   [0.0006501118555305548, -0.01296021932988484, ...
# 73   [-0.004430474304345773, -0.003785927828306199,...
# 146  [-0.002473588947416251, -0.007249899423694624,...
# 38   [0.01782363282138361, -0.029035678157550305, -...
# 102  [0.0039920407403458615, -0.03305868886222887, ...
# 103  [0.01181112997135051, -0.005047407562014621, 0...
# 99   [0.01263989074247159, -0.02687309749885153, 5....
# 20   [0.02063384922450173, -0.03449906176782845, -8...
# 45   [-0.006722510473479031, -0.006786656714190542,...
# 54   [-0.005013959162918022, -0.013115427552652978,...
# 5    [0.0041248311116142905, -0.0101907599839009, 0...
# 109  [0.019771875573536504, -0.018061205525447127, ...
# 159  [0.002447840594631745, -0.032608223146113884, ...
# 112  [0.017301640971451288, -0.01812905772834621, 0...
# 120  [0.024705435135228538, -0.030536531233419543, ...
# 116  [0.014729287576414266, -0.017196888222079633, ...
# 63   [-0.011686689293953492, -0.028376625630755475,...
# 32   [0.007075701929920252, -0.025352974006484463, ...
# 28   [0.024887955580451628, -0.028757144648727785, ...
# 48   [0.02391930757666811, -0.018322802328275052, 0...
# 46   [0.031058207435627382, -0.03317524522793775, 0...
# 10   [0.008936004627042462, -0.02502081332824792, 0...
# 122  [0.02354682399804256, -0.018110945641058026, 0...
# 58   [0.01758550715104236, -0.0146545883612127, 0.0...
# 83   [0.012080543671818853, -0.02023045934782924, 0...
# 67   [0.021329372649232955, -0.027721778807476397, ...
# 150  [-0.003917575363223401, -0.0245823209187325, 0...
# 152  [0.013741826331133047, -0.027278933063784615, ...
# 71   [0.005421793761686511, -0.045781252590234404, ...
# 84   [0.003975390574152826, -0.03743519744688888, 0...
# 1    [0.004671733160653921, -0.025517500524953052, ...
# 135  [0.007358891808987733, -0.03831379688661454, 0...
# 128  [0.0010963759527512077, -0.020290945989767304,...
# 80   [0.0009989410895248083, -0.024318655848078106,...
#
#                                       Context Entities  \
# 40      [{'entityType': 'ORG', 'value': 'ZGT Almelo'}]
# 97   [{'entityType': 'Phone', 'value': '+3188708539...
# 158  [{'entityType': 'Phone', 'value': '+3188383830...
# 154  [{'entityType': 'Phone', 'value': '+3188708330...
# 95   [{'entityType': 'ORG', 'value': 'Borstkliniek ...
# 93   [{'entityType': 'Phone', 'value': '+3188708516...
# 88   [{'entityType': 'Phone', 'value': '+3188708524...
# 91   [{'entityType': 'Email', 'value': 'secretariaa...
# 24   [{'entityType': 'ORG', 'value': 'ZGT'}, {'enti...
# 136            [{'entityType': 'ORG', 'value': 'ZGT'}]
# 16   [{'entityType': 'MISC', 'value': 'MijnZGT'}, {...
# 138  [{'entityType': 'MISC', 'value': 'VFC'}, {'ent...
# 6    [{'entityType': 'MISC', 'value': 'Bryant-tract...
# 142     [{'entityType': 'ORG', 'value': 'ZGT Almelo'}]
# 86             [{'entityType': 'PER', 'value': 'PSG'}]
# 73                                                  []
# 146  [{'entityType': 'MISC', 'value': 'PYP'}, {'ent...
# 38            [{'entityType': 'MISC', 'value': 'POS'}]
# 102                                                 []
# 103                                                 []
# 99                                                  []
# 20                                                  []
# 45                                                  []
# 54   [{'entityType': 'MISC', 'value': 'PYP'}, {'ent...
# 5        [{'entityType': 'MISC', 'value': 'MDL-arts'}]
# 109                                                 []
# 159                                                 []
# 112                                                 []
# 120  [{'entityType': 'MISC', 'value': 'Post intensi...
# 116  [{'entityType': 'MISC', 'value': 'Programma Te...
# 63                                                  []
# 32             [{'entityType': 'LOC', 'value': 'ZGT'}]
# 28   [{'entityType': 'ORG', 'value': 'Klachtenonder...
# 48   [{'entityType': 'MISC', 'value': 'Bryant-tract...
# 46                                                  []
# 10                                                  []
# 122                                                 []
# 58   [{'entityType': 'ORG', 'value': 'ZGT'}, {'enti...
# 83             [{'entityType': 'ORG', 'value': 'ZGT'}]
# 67                                                  []
# 150  [{'entityType': 'Phone', 'value': '+3188708322...
# 152  [{'entityType': 'PER', 'value': 'POS'}, {'enti...
# 71             [{'entityType': 'ORG', 'value': 'UWV'}]
# 84   [{'entityType': 'ORG', 'value': 'Nederlandse V...
# 1                                                   []
# 135  [{'entityType': 'MISC', 'value': 'EUG'}, {'ent...
# 128                                                 []
# 80                                                  []
#
#                                      Question Entities  \
# 40                                                  []
# 97             [{'entityType': 'ORG', 'value': 'ZGT'}]
# 158      [{'entityType': 'LOC', 'value': 'Roessingh'}]
# 154                                                 []
# 95                                                  []
# 93                                                  []
# 88                                                  []
# 91                                                  []
# 24                                                  []
# 136            [{'entityType': 'ORG', 'value': 'ZGT'}]
# 16        [{'entityType': 'MISC', 'value': 'MijnZGT'}]
# 138  [{'entityType': 'ORG', 'value': 'VFC'}, {'enti...
# 6    [{'entityType': 'MISC', 'value': 'Bryant-tract...
# 142                                                 []
# 86            [{'entityType': 'MISC', 'value': 'PSG'}]
# 73   [{'entityType': 'MISC', 'value': 'Echocardiogr...
# 146                                                 []
# 38                                                  []
# 102                                                 []
# 103                                                 []
# 99                                                  []
# 20                                                  []
# 45                                                  []
# 54   [{'entityType': 'MISC', 'value': 'Ejectiefract...
# 5                                                   []
# 109                                                 []
# 159                                                 []
# 112                                                 []
# 120             [{'entityType': 'ORG', 'value': 'IC'}]
# 116                                                 []
# 63                                                  []
# 32             [{'entityType': 'LOC', 'value': 'ZGT'}]
# 28   [{'entityType': 'MISC', 'value': 'Klachtenrege...
# 48                                                  []
# 46                                                  []
# 10      [{'entityType': 'MISC', 'value': 'Antegrade'}]
# 122                                                 []
# 58                                                  []
# 83                                                  []
# 67                                                  []
# 150                                                 []
# 152       [{'entityType': 'MISC', 'value': 'MijnZGT'}]
# 71                                                  []
# 84            [{'entityType': 'ORG', 'value': 'NVOG'}]
# 1                                                   []
# 135           [{'entityType': 'MISC', 'value': 'EUG'}]
# 128                                                 []
# 80                                                  []
#
#                                        Answer Entities  Entity Match  \
# 40                                                  []          True
# 97             [{'entityType': 'ORG', 'value': 'ZGT'}]          True
# 158  [{'entityType': 'LOC', 'value': 'Roessingh'}, ...          True
# 154                                                 []          True
# 95                                                  []          True
# 93                                                  []          True
# 88                                                  []          True
# 91                                                  []          True
# 24                                                  []          True
# 136            [{'entityType': 'ORG', 'value': 'ZGT'}]          True
# 16   [{'entityType': 'MISC', 'value': 'MijnZGT'}, {...         False
# 138  [{'entityType': 'MISC', 'value': 'VFC'}, {'ent...          True
# 6    [{'entityType': 'MISC', 'value': 'Bryant-tract...          True
# 142                                                 []          True
# 86                                                  []          True
# 73   [{'entityType': 'MISC', 'value': 'Echocardiogr...         False
# 146                                                 []          True
# 38                                                  []          True
# 102                                                 []          True
# 103                                                 []          True
# 99                                                  []          True
# 20                                                  []          True
# 45                                                  []          True
# 54                                                  []          True
# 5                                                   []          True
# 109                                                 []          True
# 159                                                 []          True
# 112                                                 []          True
# 120  [{'entityType': 'MISC', 'value': 'IC-opname'},...         False
# 116                                                 []          True
# 63      [{'entityType': 'MISC', 'value': 'Antegrade'}]         False
# 32                                                  []          True
# 28   [{'entityType': 'MISC', 'value': 'Klachtenrege...         False
# 48                                                  []          True
# 46                                                  []          True
# 10                                                  []          True
# 122                                                 []          True
# 58                                                  []          True
# 83             [{'entityType': 'ORG', 'value': 'ZGT'}]          True
# 67                                                  []          True
# 150                                                 []          True
# 152       [{'entityType': 'MISC', 'value': 'MijnZGT'}]          True
# 71             [{'entityType': 'ORG', 'value': 'UWV'}]          True
# 84   [{'entityType': 'ORG', 'value': 'NVOG'}, {'ent...          True
# 1                                                   []          True
# 135                                                 []          True
# 128                                                 []          True
# 80                                                  []          True
#
#      LLM Score  Unnamed: 0
# 40        90.0         NaN
# 97       100.0         NaN
# 158       80.0         NaN
# 154      100.0         NaN
# 95       100.0         NaN
# 93       100.0         NaN
# 88       100.0         NaN
# 91       100.0         NaN
# 24       100.0         NaN
# 136      100.0         NaN
# 16       100.0         NaN
# 138      100.0         NaN
# 6        100.0         NaN
# 142      100.0         NaN
# 86        80.0         NaN
# 73       100.0         NaN
# 146      100.0         NaN
# 38       100.0         NaN
# 102       95.0         NaN
# 103      100.0         NaN
# 99       100.0         NaN
# 20       100.0         NaN
# 45        90.0         NaN
# 54       100.0         NaN
# 5        100.0         NaN
# 109      100.0         NaN
# 159       90.0         NaN
# 112      100.0         NaN
# 120       95.0         NaN
# 116      100.0         NaN
# 63       100.0         NaN
# 32       100.0         NaN
# 28       100.0         NaN
# 48       100.0         NaN
# 46       100.0         NaN
# 10       100.0         NaN
# 122      100.0         NaN
# 58       100.0         NaN
# 83        90.0         NaN
# 67       100.0         NaN
# 150      100.0         NaN
# 152      100.0         NaN
# 71        90.0         NaN
# 84       100.0         NaN
# 1        100.0         NaN
# 135      100.0         NaN
# 128      100.0         NaN
# 80       100.0         NaN

# %% [markdown]
# # Fact Q&A

# %%
sample = loadData(fname, basepath)

sample['Context Entities'] = sample['Document'].apply(extract_all_entities)

new_questions_df = generateFactQuestions(sample)
new_questions_df.to_csv(f"{basepath}/output_fact_raw_{fname}.csv")
df = vectorFilter(new_questions_df)
df = llmScore(df)
df = filterFactQuestionCorrectness(df)

## take top one for each doc
df['Fact Value'] = df['Fact'].apply(lambda x: x.get('value'))
idx = df.groupby(['Document', 'Fact Value'])['LLM Score'].idxmax()
df = df.loc[idx]
# Out:
# Generating Fact QAs:   0%|          | 0/50 [00:00<?, ?it/s]
# {'entityType': 'Phone', 'value': '+31887083220'}
# {'entityType': 'Phone', 'value': '+31887083220'}
# {'entityType': 'Phone', 'value': '+31887083220'}
# {'entityType': 'Phone', 'value': '+31887083220'}
# {'entityType': 'Phone', 'value': '+31887083220'}
# {'entityType': 'Email', 'value': 'dietisten@zgt.nl'}
# {'entityType': 'Email', 'value': 'dietisten@zgt.nl'}
# {'entityType': 'Email', 'value': 'dietisten@zgt.nl'}
# {'entityType': 'Email', 'value': 'dietisten@zgt.nl'}
# {'entityType': 'Email', 'value': 'dietisten@zgt.nl'}
# {'entityType': 'Phone', 'value': '+31887083220'}
# {'entityType': 'Phone', 'value': '+31887083220'}
# {'entityType': 'Phone', 'value': '+31887083220'}
# {'entityType': 'Phone', 'value': '+31887083220'}
# {'entityType': 'Phone', 'value': '+31887083220'}
# Generating Fact QAs:   6%|▌         | 3/50 [00:27<07:07,  9.09s/it]
# {'entityType': 'Email', 'value': 'dietisten@zgt.nl'}
# {'entityType': 'Email', 'value': 'dietisten@zgt.nl'}
# {'entityType': 'Email', 'value': 'dietisten@zgt.nl'}
# {'entityType': 'Email', 'value': 'dietisten@zgt.nl'}
# {'entityType': 'Email', 'value': 'dietisten@zgt.nl'}
# {'entityType': 'Phone', 'value': '+31887085243'}
# {'entityType': 'Phone', 'value': '+31887085243'}
# {'entityType': 'Phone', 'value': '+31887085243'}
# {'entityType': 'Phone', 'value': '+31887085243'}
# {'entityType': 'Phone', 'value': '+31887085243'}
# Generating Fact QAs:  54%|█████▍    | 27/50 [00:36<00:24,  1.07s/it]
# {'entityType': 'Phone', 'value': '+31887085243'}
# {'entityType': 'Phone', 'value': '+31887085243'}
# {'entityType': 'Phone', 'value': '+31887085243'}
# {'entityType': 'Phone', 'value': '+31887085243'}
# {'entityType': 'Phone', 'value': '+31887085243'}
# {'entityType': 'Email', 'value': 'secretariaat@schisis-team.nl'}
# {'entityType': 'Email', 'value': 'secretariaat@schisis-team.nl'}
# {'entityType': 'Email', 'value': 'secretariaat@schisis-team.nl'}
# {'entityType': 'Email', 'value': 'secretariaat@schisis-team.nl'}
# {'entityType': 'Email', 'value': 'secretariaat@schisis-team.nl'}
# Generating Fact QAs:  56%|█████▌    | 28/50 [00:46<00:33,  1.54s/it]
# {'entityType': 'Email', 'value': 'secretariaat@schisis-team.nl'}
# {'entityType': 'Email', 'value': 'secretariaat@schisis-team.nl'}
# {'entityType': 'Email', 'value': 'secretariaat@schisis-team.nl'}
# {'entityType': 'Email', 'value': 'secretariaat@schisis-team.nl'}
# {'entityType': 'Email', 'value': 'secretariaat@schisis-team.nl'}
# {'entityType': 'Phone', 'value': '+31887085169'}
# {'entityType': 'Phone', 'value': '+31887085169'}
# {'entityType': 'Phone', 'value': '+31887085169'}
# {'entityType': 'Phone', 'value': '+31887085169'}
# {'entityType': 'Phone', 'value': '+31887085169'}
# Generating Fact QAs:  58%|█████▊    | 29/50 [00:55<00:43,  2.07s/it]
# {'entityType': 'Phone', 'value': '+31887085169'}
# {'entityType': 'Phone', 'value': '+31887085169'}
# {'entityType': 'Phone', 'value': '+31887085169'}
# {'entityType': 'Phone', 'value': '+31887085169'}
# {'entityType': 'Phone', 'value': '+31887085169'}
# {'entityType': 'Phone', 'value': '+31887083300'}
# {'entityType': 'Phone', 'value': '+31887083300'}
# {'entityType': 'Phone', 'value': '+31887083300'}
# {'entityType': 'Phone', 'value': '+31887083300'}
# {'entityType': 'Phone', 'value': '+31887083300'}
# {'entityType': 'Email', 'value': 'hartrevalidatie@zgt.nl'}
# {'entityType': 'Email', 'value': 'hartrevalidatie@zgt.nl'}
# {'entityType': 'Email', 'value': 'hartrevalidatie@zgt.nl'}
# {'entityType': 'Email', 'value': 'hartrevalidatie@zgt.nl'}
# {'entityType': 'Email', 'value': 'hartrevalidatie@zgt.nl'}
# {'entityType': 'Phone', 'value': '+31887083300'}
# {'entityType': 'Phone', 'value': '+31887083300'}
# {'entityType': 'Phone', 'value': '+31887083300'}
# {'entityType': 'Phone', 'value': '+31887083300'}
# {'entityType': 'Phone', 'value': '+31887083300'}
# Generating Fact QAs:  60%|██████    | 30/50 [01:12<01:08,  3.43s/it]
# {'entityType': 'Email', 'value': 'hartrevalidatie@zgt.nl'}
# {'entityType': 'Email', 'value': 'hartrevalidatie@zgt.nl'}
# {'entityType': 'Email', 'value': 'hartrevalidatie@zgt.nl'}
# {'entityType': 'Email', 'value': 'hartrevalidatie@zgt.nl'}
# {'entityType': 'Email', 'value': 'hartrevalidatie@zgt.nl'}
# {'entityType': 'Phone', 'value': '+31887083310'}
# {'entityType': 'Phone', 'value': '+31887083310'}
# {'entityType': 'Phone', 'value': '+31887083310'}
# {'entityType': 'Phone', 'value': '+31887083310'}
# {'entityType': 'Phone', 'value': '+31887083310'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887085311'}
# {'entityType': 'Phone', 'value': '+31887085311'}
# {'entityType': 'Phone', 'value': '+31887085311'}
# {'entityType': 'Phone', 'value': '+31887085311'}
# {'entityType': 'Phone', 'value': '+31887085311'}
# {'entityType': 'Phone', 'value': '+31887083923'}
# {'entityType': 'Phone', 'value': '+31887083923'}
# {'entityType': 'Phone', 'value': '+31887083923'}
# {'entityType': 'Phone', 'value': '+31887083923'}
# {'entityType': 'Phone', 'value': '+31887083923'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083310'}
# {'entityType': 'Phone', 'value': '+31887083310'}
# {'entityType': 'Phone', 'value': '+31887083310'}
# {'entityType': 'Phone', 'value': '+31887083310'}
# {'entityType': 'Phone', 'value': '+31887083310'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887085311'}
# {'entityType': 'Phone', 'value': '+31887085311'}
# {'entityType': 'Phone', 'value': '+31887085311'}
# {'entityType': 'Phone', 'value': '+31887085311'}
# {'entityType': 'Phone', 'value': '+31887085311'}
# {'entityType': 'Phone', 'value': '+31887083923'}
# {'entityType': 'Phone', 'value': '+31887083923'}
# {'entityType': 'Phone', 'value': '+31887083923'}
# {'entityType': 'Phone', 'value': '+31887083923'}
# {'entityType': 'Phone', 'value': '+31887083923'}
# Generating Fact QAs:  64%|██████▍   | 32/50 [02:37<03:24, 11.35s/it]
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887083210'}
# {'entityType': 'Phone', 'value': '+31887085396'}
# {'entityType': 'Phone', 'value': '+31887085396'}
# {'entityType': 'Phone', 'value': '+31887085396'}
# {'entityType': 'Phone', 'value': '+31887085396'}
# {'entityType': 'Phone', 'value': '+31887085396'}
# {'entityType': 'Phone', 'value': '+31887084228'}
# {'entityType': 'Phone', 'value': '+31887084228'}
# {'entityType': 'Phone', 'value': '+31887084228'}
# {'entityType': 'Phone', 'value': '+31887084228'}
# {'entityType': 'Phone', 'value': '+31887084228'}
# {'entityType': 'Phone', 'value': '+31887085396'}
# {'entityType': 'Phone', 'value': '+31887085396'}
# {'entityType': 'Phone', 'value': '+31887085396'}
# {'entityType': 'Phone', 'value': '+31887085396'}
# {'entityType': 'Phone', 'value': '+31887085396'}
# Generating Fact QAs:  66%|██████▌   | 33/50 [03:04<03:47, 13.36s/it]
# {'entityType': 'Phone', 'value': '+31887084228'}
# {'entityType': 'Phone', 'value': '+31887084228'}
# {'entityType': 'Phone', 'value': '+31887084228'}
# {'entityType': 'Phone', 'value': '+31887084228'}
# {'entityType': 'Phone', 'value': '+31887084228'}
# {'entityType': 'Phone', 'value': '+31883838300'}
# {'entityType': 'Phone', 'value': '+31883838300'}
# {'entityType': 'Phone', 'value': '+31883838300'}
# {'entityType': 'Phone', 'value': '+31883838300'}
# {'entityType': 'Phone', 'value': '+31883838300'}
# {'entityType': 'Phone', 'value': '+319003000300'}
# {'entityType': 'Phone', 'value': '+319003000300'}
# {'entityType': 'Phone', 'value': '+319003000300'}
# {'entityType': 'Phone', 'value': '+319003000300'}
# {'entityType': 'Phone', 'value': '+319003000300'}
# {'entityType': 'Phone', 'value': '+31263512512'}
# {'entityType': 'Phone', 'value': '+31263512512'}
# {'entityType': 'Phone', 'value': '+31263512512'}
# {'entityType': 'Phone', 'value': '+31263512512'}
# {'entityType': 'Phone', 'value': '+31263512512'}
# {'entityType': 'Phone', 'value': '+31703604816'}
# {'entityType': 'Phone', 'value': '+31703604816'}
# {'entityType': 'Phone', 'value': '+31703604816'}
# {'entityType': 'Phone', 'value': '+31703604816'}
# {'entityType': 'Phone', 'value': '+31703604816'}
# {'entityType': 'Phone', 'value': '+31883838300'}
# {'entityType': 'Phone', 'value': '+31883838300'}
# {'entityType': 'Phone', 'value': '+31883838300'}
# {'entityType': 'Phone', 'value': '+31883838300'}
# {'entityType': 'Phone', 'value': '+31883838300'}
# {'entityType': 'Phone', 'value': '+319003000300'}
# {'entityType': 'Phone', 'value': '+319003000300'}
# {'entityType': 'Phone', 'value': '+319003000300'}
# {'entityType': 'Phone', 'value': '+319003000300'}
# {'entityType': 'Phone', 'value': '+319003000300'}
# {'entityType': 'Phone', 'value': '+31703604816'}
# {'entityType': 'Phone', 'value': '+31703604816'}
# {'entityType': 'Phone', 'value': '+31703604816'}
# {'entityType': 'Phone', 'value': '+31703604816'}
# {'entityType': 'Phone', 'value': '+31703604816'}
# Generating Fact QAs: 100%|██████████| 50/50 [04:26<00:00,  5.33s/it]

# %%
df.to_csv(f"{basepath}/output_full_fact_{fname}.csv")
df.to_csv(f"{basepath}/output_fact_{fname}.csv", columns = ['topic_id', 'filename', 'header', 'section_text', 'Fact', 'Question', 'Answer'])
